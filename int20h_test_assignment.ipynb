# %% [markdown]
# # Int20h Test Assignement
# by The Fractal Rhapsody

# %% [markdown]
# ## Data Preproccesing

# %% [markdown]
# Importing the data:

# %%
import numpy as np
import pandas as pd
import json

data = pd.read_csv('int20h-ds-test-dataset.csv')
data
# Out:
#                                  userid user_state  \
# 0      c95c777785faec8dd910d019d7278ebe         CA
# 1      c95c777785faec8dd910d019d7278ebe         CA
# 2      f344be2d9a042b7444f3cc5279e38ef1         FL
# 3      c95c777785faec8dd910d019d7278ebe         CA
# 4      e331ed81422d8fba55520a43a872e701         IL
# ...                                 ...        ...
# 23352  679eba26c4e75e0afb178360becfa21b         CA
# 23353  679eba26c4e75e0afb178360becfa21b         CA
# 23354  679eba26c4e75e0afb178360becfa21b         CA
# 23355  679eba26c4e75e0afb178360becfa21b         CA
# 23356  679eba26c4e75e0afb178360becfa21b         CA
#
#                        event_name  \
# 0             Add Vehicle Success
# 1               Add Vehicle Break
# 2                 Calculator View
# 3      Add Payment Method Success
# 4                 Sign Up Success
# ...                           ...
# 23352  Add Payment Method Success
# 23353  Account Setup Profile Skip
# 23354  Account Setup Profile Skip
# 23355    Chat Conversation Opened
# 23356        Subscription Premium
#
#                                         event_attributes   event_created_date  \
# 0      {"Make":"Dodge","Model":"Caravan","Color":"Whi...  2022-01-16 17:03:04
# 1                                                     {}  2022-01-16 17:07:47
# 2                                                     {}  2022-01-16 17:16:25
# 3         {"Payment Method":"Credit","Tokenized Pay":""}  2022-01-16 17:24:22
# 4                                     {"Method":"Apple"}  2022-01-16 17:34:51
# ...                                                  ...                  ...
# 23352  {"Payment Method":"Credit","Tokenized Pay":"",...  2022-04-16 20:49:24
# 23353                               {"Screen":"Address"}  2022-04-16 20:50:05
# 23354                          {"Screen":"Phone Number"}  2022-04-16 20:50:10
# 23355         {"From":"Dashboard","Transaction type":""}  2022-04-16 20:50:31
# 23356  {"Start Date":"2022-04-16","Renewal Date":"202...  2022-04-16 20:50:39
#
#       event_platform device_manufacture device_model
# 0            android            samsung     SM-N975U
# 1            android            samsung     SM-N975U
# 2            android            samsung    SM-G973U1
# 3            android            samsung     SM-N975U
# 4                ios              Apple   iPhone12,1
# ...              ...                ...          ...
# 23352        android             Google     Pixel 3a
# 23353        android             Google     Pixel 3a
# 23354        android             Google     Pixel 3a
# 23355        android             Google     Pixel 3a
# 23356      outofband                NaN          NaN
#
# [23357 rows x 8 columns]

# %% [markdown]
# Transforming event time to `pd.DateTime` format:

# %%
data['event_created_date'] = pd.to_datetime(data.event_created_date)

# %% [markdown]
# Data overview:

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23357 entries, 0 to 23356
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userid              23357 non-null  object
#  1   user_state          23286 non-null  object
#  2   event_name          23357 non-null  object
#  3   event_attributes    23357 non-null  object
#  4   event_created_date  23357 non-null  datetime64[ns]
#  5   event_platform      23357 non-null  object
#  6   device_manufacture  15847 non-null  object
#  7   device_model        15847 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 1.4+ MB
# <ipython-input-5-1c31c1101f98>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe()
#                                   userid user_state event_name  \
# count                              23357      23286      23357
# unique                              3540         49         23
# top     627f50253b42607513a1c93bb68201ad         CA      Order
# freq                                 498       8627       6116
# first                                NaN        NaN        NaN
# last                                 NaN        NaN        NaN
#
#                      event_attributes   event_created_date event_platform  \
# count                           23357                23357          23357
# unique                           2309                20452              3
# top     {"Premium Membership":"True"}  2022-03-16 08:20:51            ios
# freq                             5451                   17           9586
# first                             NaN  2022-01-15 02:06:43            NaN
# last                              NaN  2022-04-16 20:50:39            NaN
#
#        device_manufacture device_model
# count               15847        15847
# unique                 22          290
# top                 Apple   iPhone12,1
# freq                 9586         1489
# first                 NaN          NaN
# last                  NaN          NaN

# %% [markdown]
# Parsing event attributes:

# %%
data['event_attributes_d'] = data.event_attributes.apply(json.loads)

# %% [markdown]
# ## Data Overview

# %% [markdown]
# Unique event categories:

# %%
possible_events  = data.event_name.unique()
possible_events
# Out:
# array(['Add Vehicle Success', 'Add Vehicle Break', 'Calculator View',
#        'Add Payment Method Success', 'Sign Up Success',
#        'Add Payment Method Failed', 'Wallet Opened', 'Transaction Refund',
#        'Email Confirmation Success', 'Account Setup Skip',
#        'Subscription Premium', 'Chat Conversation Opened',
#        'Account Setup Profile Skip',
#        'Account History Transaction Details', 'Sign Out',
#        'Chat Conversation Started', 'Order', 'Sign Up Error',
#        'Subscription Premium Cancel', 'Calculator Used',
#        'Subscription Premium Renew', 'Add Vehicle Failed',
#        'Reset Password Set'], dtype=object)

# %%
target_event = 'Subscription Premium Cancel'
# to Cancel sub we at first must have sub, presence of events
# Subscription Premium and Subscription Premium Renew means that condition is satisfied
# But it is possible that someone started long-term sub before our time range : 2022-01-15 02:06:43 - 2022-04-16 20:50:39	
# So lets look on event attributes:
for event in possible_events:
    print(f"event: {event} possible attributes combinations:\n")
    print("\n".join(data[data.event_name == event].event_attributes_d.apply(lambda x: ", ".join(sorted(list(set(x.keys()))))).unique()))
    print('----------')
# Out:
# event: Add Vehicle Success possible attributes combinations:
#
# Color, End Date, Make, Model, Rental state, Start Date, Temporary, Year
# Color, Make, Model, Temporary, Year
# Color, End Date, Make, Model, Rental State, Start Date, Temporary, Year
# ----------
# event: Add Vehicle Break possible attributes combinations:
#
#
# ----------
# event: Calculator View possible attributes combinations:
#
#
# ----------
# event: Add Payment Method Success possible attributes combinations:
#
# Payment Method, Tokenized Pay
# Payment Method
# Payment Method, Promo code, Tokenized Pay
# Payment Method, Promo code
# ----------
# event: Sign Up Success possible attributes combinations:
#
# Method
# ----------
# event: Add Payment Method Failed possible attributes combinations:
#
# Error Code, Error Message, Payment Method
# Error Code, Error Message, Payment Method, Tokenized Pay
# ----------
# event: Wallet Opened possible attributes combinations:
#
#
# ----------
# event: Transaction Refund possible attributes combinations:
#
# Amount, Id
# ----------
# event: Email Confirmation Success possible attributes combinations:
#
# Required
#
# ----------
# event: Account Setup Skip possible attributes combinations:
#
#
# ----------
# event: Subscription Premium possible attributes combinations:
#
# Membership Type, Renewal Date, Start Date
# ----------
# event: Chat Conversation Opened possible attributes combinations:
#
# From
# From, Transaction type
#
# From, Transaction Type
# ----------
# event: Account Setup Profile Skip possible attributes combinations:
#
# Screen
# ----------
# event: Account History Transaction Details possible attributes combinations:
#
# Navigated From, Type
# Navigated From, Status, Type
# ----------
# event: Sign Out possible attributes combinations:
#
# Type
# ----------
# event: Chat Conversation Started possible attributes combinations:
#
#
# ----------
# event: Order possible attributes combinations:
#
# Premium Membership
# ----------
# event: Sign Up Error possible attributes combinations:
#
# Description, Method
# ----------
# event: Subscription Premium Cancel possible attributes combinations:
#
#
# ----------
# event: Calculator Used possible attributes combinations:
#
#
# Google Map Installed, Selected Route Type
# ----------
# event: Subscription Premium Renew possible attributes combinations:
#
# Membership Type, Renewal Date, Start Date
# ----------
# event: Add Vehicle Failed possible attributes combinations:
#
# Error Code, Error Message
# ----------
# event: Reset Password Set possible attributes combinations:
#
#
# ----------

# %% [markdown]
# From the cell above, we saw that the `Subscription Premium Cancel` event has no attributes. It could be beneficial to store some details for further analysis.
#
# As we see, the `Order` event also contains some info about Premium. But since we have no information about what that application is, it is possible that the `Premium Membership` attribute belongs to another types of users.

# %%
orders = data[data.event_name == "Order"]
orders.head()
# Out:
#                               userid user_state event_name  \
# 72  0d51394c39dbf15021ccd09155ee6257         FL      Order
# 73  0d51394c39dbf15021ccd09155ee6257         FL      Order
# 74  0d51394c39dbf15021ccd09155ee6257         FL      Order
# 75  0d51394c39dbf15021ccd09155ee6257         FL      Order
# 94  4949c7b6dfa8cef23d641fd98d50ab18         TX      Order
#
#                  event_attributes  event_created_date event_platform  \
# 72  {"Premium Membership":"True"} 2022-01-15 09:23:48      outofband
# 73  {"Premium Membership":"True"} 2022-01-15 09:23:48      outofband
# 74  {"Premium Membership":"True"} 2022-01-15 10:16:12      outofband
# 75  {"Premium Membership":"True"} 2022-01-15 10:16:12      outofband
# 94  {"Premium Membership":"True"} 2022-01-17 06:42:11      outofband
#
#    device_manufacture device_model              event_attributes_d
# 72                NaN          NaN  {'Premium Membership': 'True'}
# 73                NaN          NaN  {'Premium Membership': 'True'}
# 74                NaN          NaN  {'Premium Membership': 'True'}
# 75                NaN          NaN  {'Premium Membership': 'True'}
# 94                NaN          NaN  {'Premium Membership': 'True'}

# %%
orders.event_attributes.unique()
# Out:
# array(['{"Premium Membership":"True"}', '{"Premium Membership":"False"}'],
#       dtype=object)

# %% [markdown]
# The vast majority of orders belongs to Premium Membership:

# %%
pd.pivot_table(orders[["event_attributes", "event_name"]], columns="event_attributes", aggfunc=len)
# Out:
# event_attributes  {"Premium Membership":"False"}  \
# event_name                                   665
#
# event_attributes  {"Premium Membership":"True"}
# event_name                                 5451

# %%
users_with_premium_order = data[data.event_attributes == '{"Premium Membership":"True"}'].userid.unique()
print(f"Number of users with Premium order: {len(users_with_premium_order)}")
# Out:
# Number of users with Premium order: 374

# %% [markdown]
# Now let's return to our Subscription Premium and Subscription Premium Renew events and look closely at the data:

# %%
data[data.event_name == "Subscription Premium"].event_attributes_d.apply(lambda x: str(set(x.keys()))).unique()
# Out:
# array(["{'Start Date', 'Membership Type', 'Renewal Date'}"], dtype=object)

# %%
data[data.event_name == "Subscription Premium Renew"].event_attributes_d.apply(lambda x: str(set(x.keys()))).unique()
# Out:
# array(["{'Start Date', 'Membership Type', 'Renewal Date'}"], dtype=object)

# %%
pd.set_option("max_colwidth", None)
pd.set_option("max_rows", None)
data[data.event_name == 'Subscription Premium'].event_attributes_d.head(20)
# Out:
# 34     {'Start Date': '2022-01-16', 'Renewal Date': '2022-02-17', 'Membership Type': 'Monthly'}
# 85     {'Start Date': '2022-01-16', 'Renewal Date': '2022-02-17', 'Membership Type': 'Monthly'}
# 119    {'Start Date': '2022-01-15', 'Renewal Date': '2022-02-16', 'Membership Type': 'Monthly'}
# 138    {'Start Date': '2022-01-15', 'Renewal Date': '2022-02-16', 'Membership Type': 'Monthly'}
# 153    {'Start Date': '2022-01-17', 'Renewal Date': '2022-02-18', 'Membership Type': 'Monthly'}
# 163    {'Start Date': '2022-01-17', 'Renewal Date': '2022-02-18', 'Membership Type': 'Monthly'}
# 172    {'Start Date': '2022-01-15', 'Renewal Date': '2022-02-16', 'Membership Type': 'Monthly'}
# 176    {'Start Date': '2022-01-15', 'Renewal Date': '2022-02-16', 'Membership Type': 'Monthly'}
# 323    {'Start Date': '2022-01-18', 'Renewal Date': '2022-02-19', 'Membership Type': 'Monthly'}
# 326    {'Start Date': '2022-01-18', 'Renewal Date': '2022-02-19', 'Membership Type': 'Monthly'}
# 336    {'Start Date': '2022-01-16', 'Renewal Date': '2022-02-17', 'Membership Type': 'Monthly'}
# 344    {'Start Date': '2022-01-16', 'Renewal Date': '2022-02-17', 'Membership Type': 'Monthly'}
# 380    {'Start Date': '2022-01-18', 'Renewal Date': '2022-02-19', 'Membership Type': 'Monthly'}
# 415    {'Start Date': '2022-01-17', 'Renewal Date': '2022-02-18', 'Membership Type': 'Monthly'}
# 457    {'Start Date': '2022-01-19', 'Renewal Date': '2022-02-20', 'Membership Type': 'Monthly'}
# 485    {'Start Date': '2022-01-19', 'Renewal Date': '2022-02-20', 'Membership Type': 'Monthly'}
# 526    {'Start Date': '2022-01-17', 'Renewal Date': '2022-02-18', 'Membership Type': 'Monthly'}
# 555    {'Start Date': '2022-01-19', 'Renewal Date': '2022-02-20', 'Membership Type': 'Monthly'}
# 570    {'Start Date': '2022-01-17', 'Renewal Date': '2022-02-18', 'Membership Type': 'Monthly'}
# 576    {'Start Date': '2022-01-18', 'Renewal Date': '2022-02-19', 'Membership Type': 'Monthly'}
# Name: event_attributes_d, dtype: object

# %%
data[data.event_name == 'Subscription Premium'].event_attributes.apply(lambda x: json.loads(x)["Membership Type"]).unique()
# Out:
# array(['Monthly'], dtype=object)

# %%
data[data.event_name == 'Subscription Premium Renew'].event_attributes.apply(lambda x: json.loads(x)["Membership Type"]).unique()
# Out:
# array(['Yearly', 'Monthly'], dtype=object)

# %%
# both events are semantically similar
# they may exist in not-overlapping time intervals (may be something on the app changed?)
data[data.event_name == 'Subscription Premium'].event_created_date.describe()
# Out:
# <ipython-input-19-775576dc7bc6>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data[data.event_name == 'Subscription Premium'].event_created_date.describe()
# count                     711
# unique                    704
# top       2022-02-18 20:40:43
# freq                        2
# first     2022-01-15 13:58:45
# last      2022-04-16 20:50:39
# Name: event_created_date, dtype: object

# %%
data[data.event_name == 'Subscription Premium Renew'].event_created_date.describe()
# Out:
# <ipython-input-20-1df01a8f1d3e>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data[data.event_name == 'Subscription Premium Renew'].event_created_date.describe()
# count                     310
# unique                    225
# top       2022-03-04 01:09:46
# freq                        5
# first     2022-01-31 01:14:26
# last      2022-04-16 01:16:52
# Name: event_created_date, dtype: object

# %% [markdown]
# As we can see, there are 4 sets of Premium users which exists simultanously:
# <li>with Premium Subscribtion event
# <li>with renewed monthly subscription
# <li>with renewed yearly subscription
# <li>with orders with ""Premium Membership":"True"" attribute
#
# Now let's look on relationships beetween those sets

# %%
users_with_renew_yearly = data.loc[data.event_name.isin([ 'Subscription Premium Renew']) & data.event_attributes.str.contains("Yearly"), "userid"].unique()
users_with_renew_monthly = data.loc[data.event_name.isin([ 'Subscription Premium Renew']) & data.event_attributes.str.contains("Monthly"), "userid"].unique()
users_with_renew = data.loc[data.event_name.isin([ 'Subscription Premium Renew']), "userid"].unique()
users_with_premimum = data.loc[data.event_name.isin(['Subscription Premium']), "userid"].unique()
users_with_premium_order = data[data.event_attributes == '{"Premium Membership":"True"}'].userid.unique()

print(f"Number of users with yearly renew: {len(users_with_renew_yearly)}")
print(f"Number of users with monthly renew: {len(users_with_renew_monthly)}")
print(f"Number of users with Premium Subscription event: {len(users_with_premimum)}")
print(f'Number of users with orders with ""Premium Membership":"True"" attribute: {len(users_with_renew_yearly)}')
print(f"Number of users: {len(data.userid.unique())}")

# len(users_with_renew_yearly), len(users_with_renew_monthly), len(users_with_premimum), len(users_with_premium_order), len(data.userid.unique())
# Out:
# Number of users with yearly renew: 110
# Number of users with monthly renew: 123
# Number of users with Premium Subscription event: 711
# Number of users with orders with ""Premium Membership":"True"" attribute: 110
# Number of users: 3540

# %%
print(f"Number of users with both premium orders and subscription events: {len(np.intersect1d(users_with_premimum, users_with_premium_order))}")
# Out:
# Number of users with both premium orders and subscription events: 320

# %%
print(f"Number of users with both yearly and monthly renew: {len(np.intersect1d(users_with_renew_yearly, users_with_renew_monthly))}")
print(f"Number of users with either yearly and monthly renew: {len(users_with_renew)}")
# renewed users cant be both simultanously
# Out:
# Number of users with both yearly and monthly renew: 0
# Number of users with either yearly and monthly renew: 233

# %%
print(f"Number of users with both yearly renew and subscription event: {len(np.intersect1d(users_with_renew_yearly, users_with_premimum))}")
print(f"Number of users with both monthly renew and subscription event: {len(np.intersect1d(users_with_renew_monthly, users_with_premimum))}")
# Out:
# Number of users with both yearly renew and subscription event: 70
# Number of users with both monthly renew and subscription event: 98

# %%
print(f"Number of users with both yearly renew and premium order event: {len(np.intersect1d(users_with_renew_yearly, users_with_premium_order))}")
print(f"Number of users with both monthly renew and premium order event: {len(np.intersect1d(users_with_renew_monthly, users_with_premium_order))}")
# Out:
# Number of users with both yearly renew and premium order event: 51
# Number of users with both monthly renew and premium order event: 67

# %% [markdown]
# Both subsets of `users_with_renew` have approximately half of the users without any order, as well as mutual overlappings of subsets are a little bit messy, so below we will introduce following features:
# <li> monthly subscription
# <li> yearly subscription
# <li> number of orders of user
#
# and drop all the users who do not have premium orders or subscriptions

# %%
users_with_any_premium = np.union1d(users_with_renew, users_with_premimum)
users_with_any_premium = np.union1d(users_with_any_premium, users_with_premium_order)
len(users_with_any_premium), len(data.userid.unique())
# Out:
# (799, 3540)

# %%
# drop events of users without Premium
data_filtered = data[data.userid.isin(users_with_any_premium)]

# drop events, which are after the Cancel event
data_filtered_ = pd.DataFrame(columns=data_filtered.columns)
for user_id in users_with_any_premium:
    user_data = data_filtered[(data_filtered.userid == user_id)]
    dates = user_data[user_data.event_name == target_event ].event_created_date.values
    if len(dates) > 0:
        dates = max(dates)
        user_data = user_data[user_data.event_created_date <= dates]
    data_filtered_ = data_filtered_.append(user_data)

len(data_filtered_), len(data)
# Out:
# (14132, 23357)

# %%
data_filtered = data_filtered_.copy()

# %% [markdown]
# Now lets look on transactional details of some possibly important transactions:

# %%
pd.set_option("max_colwidth", None)
pd.set_option("max_rows", None)
data_filtered[data_filtered.event_attributes.str.contains('Error Message')][["event_name", "event_attributes"]]
#813	Add Payment Method Failed	{"Error Code":"ERROR-NaN10","Error Message":"Postal code can only contain letters,
#                                   numbers, spaces, and hyphens.","Payment Method":"Credit Card"}
# NAaN in Error Code is very very ODD, looks like there are bug in your database
# Out:
#                       event_name  \
# 160    Add Payment Method Failed
# 161    Add Payment Method Failed
# 321    Add Payment Method Failed
# 701    Add Payment Method Failed
# 813    Add Payment Method Failed
# 1102   Add Payment Method Failed
# 2010   Add Payment Method Failed
# 2013   Add Payment Method Failed
# 2338   Add Payment Method Failed
# 2339   Add Payment Method Failed
# 2377   Add Payment Method Failed
# 2460   Add Payment Method Failed
# 2516   Add Payment Method Failed
# 2867   Add Payment Method Failed
# 3181   Add Payment Method Failed
# 3182   Add Payment Method Failed
# 3183   Add Payment Method Failed
# 3846   Add Payment Method Failed
# 4549   Add Payment Method Failed
# 4615   Add Payment Method Failed
# 5168   Add Payment Method Failed
# 5759   Add Payment Method Failed
# 5880   Add Payment Method Failed
# 6614   Add Payment Method Failed
# 6678   Add Payment Method Failed
# 6679   Add Payment Method Failed
# 7219   Add Payment Method Failed
# 8145   Add Payment Method Failed
# 8194   Add Payment Method Failed
# 9314   Add Payment Method Failed
# 9724   Add Payment Method Failed
# 9776   Add Payment Method Failed
# 9777   Add Payment Method Failed
# 10190  Add Payment Method Failed
# 10191  Add Payment Method Failed
# 10192  Add Payment Method Failed
# 10238  Add Payment Method Failed
# 10599         Add Vehicle Failed
# 10711  Add Payment Method Failed
# 11614  Add Payment Method Failed
# 11615  Add Payment Method Failed
# 12881  Add Payment Method Failed
# 12887  Add Payment Method Failed
# 13510  Add Payment Method Failed
# 13607  Add Payment Method Failed
# 13608  Add Payment Method Failed
# 13659  Add Payment Method Failed
# 13663  Add Payment Method Failed
# 13890  Add Payment Method Failed
# 13989  Add Payment Method Failed
# 14019  Add Payment Method Failed
# 14429  Add Payment Method Failed
# 15285  Add Payment Method Failed
# 15934         Add Vehicle Failed
# 16167  Add Payment Method Failed
# 16168  Add Payment Method Failed
# 16169  Add Payment Method Failed
# 16170  Add Payment Method Failed
# 16189  Add Payment Method Failed
# 16190  Add Payment Method Failed
# 16854  Add Payment Method Failed
# 17170  Add Payment Method Failed
# 17171  Add Payment Method Failed
# 17230  Add Payment Method Failed
# 17384  Add Payment Method Failed
# 17385  Add Payment Method Failed
# 17402  Add Payment Method Failed
# 17403  Add Payment Method Failed
# 17404  Add Payment Method Failed
# 17613  Add Payment Method Failed
# 17646  Add Payment Method Failed
# 17877  Add Payment Method Failed
# 17878  Add Payment Method Failed
# 17984         Add Vehicle Failed
# 17985         Add Vehicle Failed
# 18832  Add Payment Method Failed
# 19064  Add Payment Method Failed
# 19065  Add Payment Method Failed
# 19066  Add Payment Method Failed
# 19336  Add Payment Method Failed
# 20405  Add Payment Method Failed
# 20678  Add Payment Method Failed
# 20866         Add Vehicle Failed
# 21521  Add Payment Method Failed
# 21522  Add Payment Method Failed
# 21679  Add Payment Method Failed
# 21756  Add Payment Method Failed
# 21757  Add Payment Method Failed
# 21758  Add Payment Method Failed
# 22204  Add Payment Method Failed
# 22205  Add Payment Method Failed
# 22206  Add Payment Method Failed
# 23062  Add Payment Method Failed
# 23063  Add Payment Method Failed
# 23065  Add Payment Method Failed
# 23127  Add Payment Method Failed
#
#                                                                                                                                                  event_attributes
# 160                        {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 161                        {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 321                                           {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 701                        {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 813             {"Error Code":"ERROR-NaN10","Error Message":"Postal code can only contain letters, numbers, spaces, and hyphens.","Payment Method":"Credit Card"}
# 1102                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 2010                                          {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 2013                                            {"Error Code":"ERROR-NaN10","Payment Method":"Credit Card","Error Message":"Payment method failed verification."}
# 2338                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 2339                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 2377                                            {"Error Code":"ERROR-NaN10","Payment Method":"Credit Card","Error Message":"Payment method failed verification."}
# 2460                                          {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 2516                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 2867                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 3181   {"Error Code":"ERROR-NaN10","Payment Method":"Credit Card","Error Message":"CVV must be 4 digits for American Express and 3 digits for other card types."}
# 3182   {"Error Code":"ERROR-NaN10","Error Message":"CVV must be 4 digits for American Express and 3 digits for other card types.","Payment Method":"Credit Card"}
# 3183   {"Error Message":"CVV must be 4 digits for American Express and 3 digits for other card types.","Payment Method":"Credit Card","Error Code":"ERROR-NaN10"}
# 3846                                          {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 4549                                          {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 4615                                          {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 5168                         {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 5759                                          {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 5880                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 6614                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 6678              {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}
# 6679                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 7219                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 8145              {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}
# 8194                       {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 9314                                          {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 9724                                          {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 9776                                          {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 9777                                          {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 10190             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required."}
# 10191                                         {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 10192                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 10238                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 10599                                        {"Error Code":"ERROR-NaN10","Error Message":"The operation couldn’t be completed. (Company.ErrorResponse error 0.)"}
# 10711             {"Error Message":"Card is debit but credit is required.","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 11614             {"Error Code":"ERROR-16010","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 11615             {"Error Code":"ERROR-16010","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 12881                                           {"Error Code":"ERROR-NaN10","Payment Method":"Credit Card","Error Message":"Payment method failed verification."}
# 12887                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 13510                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 13607             {"Error Message":"Card is debit but credit is required.","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 13608                                         {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 13659             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required."}
# 13663             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010"}
# 13890                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 13989                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 14019                                           {"Error Code":"ERROR-NaN10","Payment Method":"Credit Card","Error Message":"Payment method failed verification."}
# 14429                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 15285                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 15934                                        {"Error Message":"The operation couldn’t be completed. (Company.ErrorResponse error 0.)","Error Code":"ERROR-NaN10"}
# 16167             {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}
# 16168                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 16169                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 16170                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 16189                                         {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 16190                                         {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card"}
# 16854                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 17170                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17171             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required."}
# 17230             {"Error Message":"Card is debit but credit is required.","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17384                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17385                                         {"Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010","Payment Method":"Credit Card"}
# 17402                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17403                                         {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card"}
# 17404                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17613             {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}
# 17646             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010"}
# 17877                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 17878                                         {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card"}
# 17984                                        {"Error Code":"ERROR-NaN10","Error Message":"The operation couldn’t be completed. (Company.ErrorResponse error 0.)"}
# 17985                                        {"Error Message":"The operation couldn’t be completed. (Company.ErrorResponse error 0.)","Error Code":"ERROR-NaN10"}
# 18832                                           {"Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Error Code":"ERROR-NaN10"}
# 19064                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 19065                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 19066                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 19336             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010"}
# 20405                        {"Error Code":"ERROR-NaN10","Error Message":"Payment method failed verification.","Payment Method":"Credit Card","Tokenized Pay":""}
# 20678                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 20866                                        {"Error Message":"The operation couldn’t be completed. (Company.ErrorResponse error 0.)","Error Code":"ERROR-NaN10"}
# 21521                                         {"Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 21522                                         {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 21679             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required."}
# 21756             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010"}
# 21757             {"Error Message":"Card is debit but credit is required.","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 21758                                         {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 22204             {"Error Message":"Card is debit but credit is required.","Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Code":"ERROR-16010"}
# 22205             {"Tokenized Pay":"Apple Pay","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required.","Error Code":"ERROR-16010"}
# 22206                                         {"Error Code":"ERROR-16010","Payment Method":"Credit Card","Error Message":"Card is debit but credit is required."}
# 23062                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 23063                      {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Credit Card","Tokenized Pay":""}
# 23065             {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}
# 23127             {"Error Code":"ERROR-16010","Error Message":"Card is debit but credit is required.","Payment Method":"Google Pay","Tokenized Pay":"Google Pay"}

# %% [markdown]
# As you can see below, all the refund amounts are negative. We will preserve the sign further:

# %%
data_filtered[data_filtered.event_name.str.contains('Refund')][["userid","event_name", "event_attributes"]]
# Out:
#                                  userid          event_name  \
# 517    430d96d025d9c30dbd62aa4fd3591e98  Transaction Refund
# 2526   242f8255937541b03a117754ad36412d  Transaction Refund
# 3112   638a7b0cb6c8c36914929f0f6dec5f99  Transaction Refund
# 3276   829ecc5ca524bdfcfe1b1e7f21d1f9c7  Transaction Refund
# 3278   83cf5f5241e85c4250279a9e47c140ba  Transaction Refund
# 3377   29c68f723b88e2d3bb1172f847b831e4  Transaction Refund
# 3378   29c68f723b88e2d3bb1172f847b831e4  Transaction Refund
# 3379   29c68f723b88e2d3bb1172f847b831e4  Transaction Refund
# 3826   258f464c03022a8510e9f4c067d1b8d7  Transaction Refund
# 3985   d13cf0b65d1701596269c4000bf647b8  Transaction Refund
# 4676   a36f9c3e8bcc3c6ac7ee75f9e08c1deb  Transaction Refund
# 4762   760a8cfc450157aaeaa91a6ec90a9230  Transaction Refund
# 4957   254eb384004de580e4840aa48dfff2c8  Transaction Refund
# 5195   340a603b92a8a87d8df54de8b3f4cebc  Transaction Refund
# 5266   2a2003f6836b4720906cbae8893faec9  Transaction Refund
# 5267   2a2003f6836b4720906cbae8893faec9  Transaction Refund
# 5616   f03ba132c763930a09d29df3c23f8bea  Transaction Refund
# 6102   5b6e0e28ca9c0ad0c28b9833e0f6f3bb  Transaction Refund
# 6164   a529249c937ee94029cde7d9de5493b7  Transaction Refund
# 6165   a529249c937ee94029cde7d9de5493b7  Transaction Refund
# 6368   a1ac89e45a6ecd464bda47f12d2ec349  Transaction Refund
# 6369   a1ac89e45a6ecd464bda47f12d2ec349  Transaction Refund
# 6734   80584b0d93d611a6fe7778907d7df02c  Transaction Refund
# 6906   0bd397383b7b3070af45cb75d9e44c30  Transaction Refund
# 7544   0fc0cec5a0e21c62feb9a7c5217c36d8  Transaction Refund
# 7545   0fc0cec5a0e21c62feb9a7c5217c36d8  Transaction Refund
# 7546   0fc0cec5a0e21c62feb9a7c5217c36d8  Transaction Refund
# 7887   13d8a03074dd4502c5acb82fc65e2b33  Transaction Refund
# 8522   73a754cf72593344bcd2412c1c24975b  Transaction Refund
# 9489   415a999a1ed566ebf7e65e950bac72fb  Transaction Refund
# 9531   57e5c76a77ab90a452aef66b3321ef94  Transaction Refund
# 10228  6a44861a524688ce200eb1dd74f1ec13  Transaction Refund
# 10247  f18c5b5b66f43b6b1294f66ab2c1e98d  Transaction Refund
# 10587  b701f724e2c62d8adbaa7da3cb1d23c6  Transaction Refund
# 10862  ab48659559affb5671813091c363e359  Transaction Refund
# 10863  ab48659559affb5671813091c363e359  Transaction Refund
# 10865  ab48659559affb5671813091c363e359  Transaction Refund
# 11143  d7c4af4c0b35871fba7967ab56458584  Transaction Refund
# 11433  e6d239e26b1205f98c76219c3beba9a8  Transaction Refund
# 11435  e6d239e26b1205f98c76219c3beba9a8  Transaction Refund
# 11436  e6d239e26b1205f98c76219c3beba9a8  Transaction Refund
# 12368  5d91115e38308fbbcf738ae08be36c0c  Transaction Refund
# 12369  2446b92327462e2127b3f2693d26c04a  Transaction Refund
# 12370  2446b92327462e2127b3f2693d26c04a  Transaction Refund
# 12388  34bc6a1b14fbd2cab9cf48521e2af7ab  Transaction Refund
# 12448  dfdd0c050e79fc5ad02384f4e1b8411c  Transaction Refund
# 12468  deda6cf730683fc85007ec28dc4fed7a  Transaction Refund
# 12638  c3f069232f632f488adf7d12bd85d1d8  Transaction Refund
# 12639  c0ce0b06f849d0a75dc3f2e69c87b0b6  Transaction Refund
# 13564  7f132284f2c53ef1d6c3b63f97a15bde  Transaction Refund
# 13646  a528cce04679dc6316925041fda7db8e  Transaction Refund
# 13680  ce3e5edb71baee282433c98abd4e6bf3  Transaction Refund
# 13691  36349bfe556825eb3041de5dec1acae3  Transaction Refund
# 13973  66b10fd6c2896eb0544358c22f857daf  Transaction Refund
# 13975  66b10fd6c2896eb0544358c22f857daf  Transaction Refund
# 14595  5643e7f48ecaaa954360dcea11326f90  Transaction Refund
# 14638  6523b0c048a6b137256cafc1523c2c2e  Transaction Refund
# 14904  79bcd342e50f3d187104aa2849b51375  Transaction Refund
# 14905  79bcd342e50f3d187104aa2849b51375  Transaction Refund
# 14977  0871c09afb84920b8bfd27b3c328c86a  Transaction Refund
# 15164  2cd321395020766bab5f3d6e98370615  Transaction Refund
# 15263  4359ebe5e116311852440785e34f916e  Transaction Refund
# 15343  459e6058a0128608eca6f2e4baffcbb6  Transaction Refund
# 15465  dedc34e3710c317acd909fc4dcbe291c  Transaction Refund
# 15644  6b03383c14cd259c5fd84d98929d8073  Transaction Refund
# 15683  7ec7d876fc0b0a266f0bbe7f1e086f16  Transaction Refund
# 15750  1ebd9a46e9d38ac548d26c24475c184a  Transaction Refund
# 15778  6447dd1e764aa2035f2ff6febdcd903b  Transaction Refund
# 16816  821444cb337f85c41d9c4f1f057a26fc  Transaction Refund
# 16817  821444cb337f85c41d9c4f1f057a26fc  Transaction Refund
# 17048  87f1b1447b0ddaff0fa63cddbe85f4e7  Transaction Refund
# 17142  da11b3720191b555d0c65e08a88334b1  Transaction Refund
# 17555  40d74d801142724f930bd784d2273059  Transaction Refund
# 17556  40d74d801142724f930bd784d2273059  Transaction Refund
# 18260  fa8574e4b97ff04270a538ab8d41a287  Transaction Refund
# 18311  ca79374cbefb71b9bdfdc7151c0c5ccf  Transaction Refund
# 18332  66b31f5f5cd3fe44a57318ede88e25f6  Transaction Refund
# 18333  66b31f5f5cd3fe44a57318ede88e25f6  Transaction Refund
# 18334  66b31f5f5cd3fe44a57318ede88e25f6  Transaction Refund
# 19036  db61a6c9d22f4fdab79d439095d667c5  Transaction Refund
# 19302  6b3bfe87a5b8f183e3cf042103e15da6  Transaction Refund
# 20153  c952231e6ea12e2bdd6f735453422008  Transaction Refund
# 20169  c1a2ab14f6f771ed1f19c1f7afb65dfa  Transaction Refund
# 20170  c1a2ab14f6f771ed1f19c1f7afb65dfa  Transaction Refund
# 21704  c003207d778544ae385fdd7decdb2793  Transaction Refund
# 21880  6500ae39d2f7d8f84514ae25ec777a90  Transaction Refund
# 21881  6500ae39d2f7d8f84514ae25ec777a90  Transaction Refund
# 21882  6500ae39d2f7d8f84514ae25ec777a90  Transaction Refund
# 22011  11b9f94b9c956fa7197e02323663a454  Transaction Refund
# 22070  5393129fdf773191f7b3de51b35bb15d  Transaction Refund
# 22071  5393129fdf773191f7b3de51b35bb15d  Transaction Refund
# 22072  5393129fdf773191f7b3de51b35bb15d  Transaction Refund
# 22073  5393129fdf773191f7b3de51b35bb15d  Transaction Refund
# 22343  cef3c13a885053350dd68b3ce64eddc7  Transaction Refund
# 22371  d7e3e10cd20069ef853b759ae4910814  Transaction Refund
# 23012  6cd4b3af304d32aefeb446632209c00d  Transaction Refund
#
#                                                   event_attributes
# 517       {"Id":"8b58302d81c15a27545e492bdbeee2ef","Amount":"-10"}
# 2526      {"Id":"570f2db617899393f6fe057112a4b894","Amount":"-50"}
# 3112      {"Id":"776d1e9a972a164f2758df79247dcf29","Amount":"-20"}
# 3276      {"Id":"350e9930fd6c550a087c5781bd1e661c","Amount":"-10"}
# 3278      {"Id":"cab720b1cb75ee0f2741cc09efb630be","Amount":"-10"}
# 3377      {"Id":"a06df3f8a4e3b4bb21ab0a01f186c3a7","Amount":"-20"}
# 3378    {"Id":"e12e7fca6bee6c15768229268fb37e5d","Amount":"-0.96"}
# 3379      {"Id":"0cc399c0a371c7a18779ed6eb7e42320","Amount":"-20"}
# 3826      {"Id":"abb700649f62a3d92ddcdf33e98862e1","Amount":"-10"}
# 3985      {"Id":"a6f3727ea2d08ba23fceb7bc2a12c389","Amount":"-20"}
# 4676   {"Id":"aa01b6224e43702c3f89fec0f893bd0a","Amount":"-16.62"}
# 4762      {"Id":"d6e6fd1ed77a4e34e6dc37d978ebeafe","Amount":"-20"}
# 4957      {"Id":"459fa7357a9138e2d9a78f2643711714","Amount":"-50"}
# 5195      {"Id":"f4a02d52c02fa2bf4a420a937f86a6ce","Amount":"-10"}
# 5266      {"Id":"1523f5e8461ce96393c2bb174dba0f29","Amount":"-20"}
# 5267    {"Id":"fd8ab9547a17a81f83c939161e973248","Amount":"-6.67"}
# 5616      {"Id":"417fb1dfecc15925902300432b3ae4ef","Amount":"-20"}
# 6102      {"Id":"20ffd92026a306dca830b6b40adb81ee","Amount":"-20"}
# 6164      {"Id":"1d65b6cbf061c7d40ae2f25ec46f742a","Amount":"-10"}
# 6165    {"Id":"836fb5e049409d25751834036707f6a7","Amount":"-8.01"}
# 6368      {"Id":"8e119890f5642dca2d37aa450b7b582e","Amount":"-20"}
# 6369   {"Id":"ac57b07101e92554970425966bd43676","Amount":"-10.87"}
# 6734      {"Id":"af041c58395bbfb7245d78c901bb6300","Amount":"-10"}
# 6906      {"Id":"cbfa941e216de1d3f2bd8f26ace2037d","Amount":"-10"}
# 7544      {"Id":"ce785427f4b3c2a038bbc18e76cec6e1","Amount":"-10"}
# 7545    {"Id":"5ed652314b516e5cb96e72a484106ff9","Amount":"-9.99"}
# 7546      {"Id":"8a53f0da2d0e0f5f579a5c97c7cf478d","Amount":"-10"}
# 7887      {"Id":"ee4ea4dce7c24010bc02dcaf21739206","Amount":"-10"}
# 8522      {"Id":"a4c72d26ed065902459115fffc3f86a4","Amount":"-10"}
# 9489      {"Id":"18c4aa8e314644d3bfd5a4ee4329c23d","Amount":"-10"}
# 9531      {"Id":"d51ddfc26d1a382dcd023161134919d3","Amount":"-10"}
# 10228     {"Id":"82aae85e13874d2d4212c67f37e98656","Amount":"-10"}
# 10247     {"Id":"90df5c8aaa1e297b21893afec9718bfa","Amount":"-10"}
# 10587     {"Id":"d357a67c9c95ef2bf8dd661f16bd24a1","Amount":"-50"}
# 10862     {"Id":"b0bf752e9d66577d9d4763a2f943d614","Amount":"-10"}
# 10863  {"Id":"ace33d4759bc2d4b3912ed4e4c8d2083","Amount":"-24.29"}
# 10865     {"Id":"69911dd238a7a67ec3f381df17938b35","Amount":"-10"}
# 11143     {"Id":"76b236559f7c0de7cc34c947d5275861","Amount":"-10"}
# 11433     {"Id":"56bd297b59815b0a9a47f412d46baefa","Amount":"-20"}
# 11435     {"Id":"aa7f453350adfb50a91d18464e9c9c26","Amount":"-20"}
# 11436  {"Id":"52ed31118120ce31d950d257e1292d3e","Amount":"-14.29"}
# 12368     {"Id":"76dbb4d971e85719cd8eda8353db8430","Amount":"-20"}
# 12369     {"Id":"6c2ad2e1f3333aad88f665453970ae98","Amount":"-10"}
# 12370  {"Id":"4fdfe77889d2727bca487b985e5258a2","Amount":"-24.29"}
# 12388     {"Id":"4fb24949db3f1675f10a3a7944abb1bd","Amount":"-20"}
# 12448     {"Id":"19cf7d26fd0b0d80c068df45219b80d8","Amount":"-20"}
# 12468     {"Id":"c7bf22b55bec8b619b7a758279c1e68b","Amount":"-50"}
# 12638     {"Id":"3f13bdc53ae75f950f141d454534591b","Amount":"-20"}
# 12639     {"Id":"1b38d1509af0376d2ae37b5d90f85179","Amount":"-10"}
# 13564     {"Id":"29a717cdd52c38edae4614c57b9ba5e6","Amount":"-10"}
# 13646     {"Id":"172fafc273d928cca2aea5989e3adc73","Amount":"-20"}
# 13680    {"Id":"fdc9a27599715f9d169f180c692a1f05","Amount":"-100"}
# 13691     {"Id":"8a2edcf889576b0e9e3cfcad74b1566f","Amount":"-10"}
# 13973  {"Id":"1046450391320660f0bf38476473a502","Amount":"-24.29"}
# 13975     {"Id":"6e11ec6468496d96d07477beadc9e5c8","Amount":"-10"}
# 14595     {"Id":"cbf30aa0674eb25b54c37bed044f220b","Amount":"-10"}
# 14638     {"Id":"fcea3f4170a5cc8b51dfea6b61d334b3","Amount":"-80"}
# 14904     {"Id":"3834b900cd4f145516d308eeb26fe1d4","Amount":"-20"}
# 14905   {"Id":"a5b116f61fb7720d5e9701f0999f3d5c","Amount":"-8.78"}
# 14977     {"Id":"85298a4db30c1fb4f302b117f0b2b0fc","Amount":"-20"}
# 15164     {"Id":"1fde8582e15d7646386087470ad06245","Amount":"-20"}
# 15263     {"Id":"f9b78cb29f97bb5a1c05942fda178de1","Amount":"-20"}
# 15343     {"Id":"330bd7a52a5cbb370f237a59aef8a48a","Amount":"-10"}
# 15465     {"Id":"327874f2ab93494082e5ed15bc7f1365","Amount":"-20"}
# 15644     {"Id":"329244637ab2dda8aa7fa16b1d124599","Amount":"-10"}
# 15683  {"Id":"ca0216784ea27370db642f70d23a1ea0","Amount":"-24.29"}
# 15750     {"Id":"8dfad62ef496f31295eaf6f14662fde9","Amount":"-20"}
# 15778     {"Id":"a1edd984408fb75728984ddbd5aca4c8","Amount":"-10"}
# 16816     {"Id":"c47fb4262c04528b6027b4f64c227618","Amount":"-40"}
# 16817     {"Id":"681a9a27035ed8fb6baafd419e06bbf2","Amount":"-20"}
# 17048     {"Id":"6928758f7c8cf5c09edb72a7e3ca86f4","Amount":"-20"}
# 17142     {"Id":"ae886bef41f1bee1fcb9b9d21453e1bd","Amount":"-50"}
# 17555     {"Id":"f00288e0289bf7240835ff2fa7e2dec2","Amount":"-20"}
# 17556   {"Id":"8b43371aa9ca1ba9f2027c5db6e83438","Amount":"-6.17"}
# 18260     {"Id":"23dbb16faaa3fa8b5e71873bc2019ad7","Amount":"-20"}
# 18311  {"Id":"7b7632be9cad73c564c2f58c4d82ae33","Amount":"-34.79"}
# 18332     {"Id":"81e1cde78cc4c68eff133c34c228ad32","Amount":"-20"}
# 18333  {"Id":"65540f23d6b27044ae38292dc8d96e40","Amount":"-18.35"}
# 18334  {"Id":"c393edb16ea62bb388b40aaa403692c7","Amount":"-15.94"}
# 19036     {"Id":"64c5ef169ff3654dd1a5413e260ced7c","Amount":"-20"}
# 19302     {"Id":"052ba99232fe3c50eef480d6fb6f362b","Amount":"-50"}
# 20153     {"Id":"dfd49addde7e9c6587df3a1633e46ae1","Amount":"-20"}
# 20169  {"Id":"c60ec833618c100200f9d563ac816d53","Amount":"-27.99"}
# 20170     {"Id":"17145833ab666170bc6225f835532a81","Amount":"-20"}
# 21704     {"Id":"ffa17017e78d166c92265aa97d515dd3","Amount":"-50"}
# 21880     {"Id":"4ab58a188b83c986e52042ed1d1d6fa8","Amount":"-20"}
# 21881  {"Id":"805a091b36d044e78410a34173becd7f","Amount":"-27.99"}
# 21882     {"Id":"954909c3d8e06eb10be9a6e688d933a2","Amount":"-20"}
# 22011     {"Id":"3857f1c2e0c0df4b42c3d0cb7839908e","Amount":"-20"}
# 22070     {"Id":"1c552859b06a1dba5f68b871a0c17016","Amount":"-20"}
# 22071  {"Id":"6a3110ac738c5eb75cfb1ff72839da15","Amount":"-22.73"}
# 22072     {"Id":"ebc7b7a62ab968796c5cf758a0e83182","Amount":"-20"}
# 22073   {"Id":"4f3c6f5ea897b5006f9e80984e10454e","Amount":"-5.26"}
# 22343     {"Id":"8fb90395f21af9e4760f84d555b83968","Amount":"-10"}
# 22371     {"Id":"3c8b2b7ed2b8063f51eb31d70ed00e26","Amount":"-20"}
# 23012     {"Id":"2e47bf350f766c32d3ff2bed4e90e7bb","Amount":"-10"}

# %%
data_filtered[data_filtered.event_name.str.contains('History')][["event_name", "event_attributes"]]
# Out:
#                                 event_name  \
# 55     Account History Transaction Details
# 139    Account History Transaction Details
# 183    Account History Transaction Details
# 188    Account History Transaction Details
# 189    Account History Transaction Details
# 190    Account History Transaction Details
# 284    Account History Transaction Details
# 345    Account History Transaction Details
# 363    Account History Transaction Details
# 364    Account History Transaction Details
# 458    Account History Transaction Details
# 459    Account History Transaction Details
# 462    Account History Transaction Details
# 486    Account History Transaction Details
# 487    Account History Transaction Details
# 544    Account History Transaction Details
# 558    Account History Transaction Details
# 583    Account History Transaction Details
# 620    Account History Transaction Details
# 674    Account History Transaction Details
# 675    Account History Transaction Details
# 676    Account History Transaction Details
# 694    Account History Transaction Details
# 704    Account History Transaction Details
# 705    Account History Transaction Details
# 706    Account History Transaction Details
# 707    Account History Transaction Details
# 708    Account History Transaction Details
# 709    Account History Transaction Details
# 710    Account History Transaction Details
# 711    Account History Transaction Details
# 712    Account History Transaction Details
# 713    Account History Transaction Details
# 714    Account History Transaction Details
# 715    Account History Transaction Details
# 736    Account History Transaction Details
# 738    Account History Transaction Details
# 786    Account History Transaction Details
# 787    Account History Transaction Details
# 788    Account History Transaction Details
# 790    Account History Transaction Details
# 791    Account History Transaction Details
# 807    Account History Transaction Details
# 808    Account History Transaction Details
# 824    Account History Transaction Details
# 830    Account History Transaction Details
# 866    Account History Transaction Details
# 867    Account History Transaction Details
# 868    Account History Transaction Details
# 869    Account History Transaction Details
# 882    Account History Transaction Details
# 885    Account History Transaction Details
# 891    Account History Transaction Details
# 924    Account History Transaction Details
# 929    Account History Transaction Details
# 935    Account History Transaction Details
# 992    Account History Transaction Details
# 998    Account History Transaction Details
# 1028   Account History Transaction Details
# 1058   Account History Transaction Details
# 1080   Account History Transaction Details
# 1089   Account History Transaction Details
# 1095   Account History Transaction Details
# 1148   Account History Transaction Details
# 1214   Account History Transaction Details
# 1217   Account History Transaction Details
# 1279   Account History Transaction Details
# 1281   Account History Transaction Details
# 1306   Account History Transaction Details
# 1309   Account History Transaction Details
# 1310   Account History Transaction Details
# 1311   Account History Transaction Details
# 1394   Account History Transaction Details
# 1395   Account History Transaction Details
# 1396   Account History Transaction Details
# 1435   Account History Transaction Details
# 1436   Account History Transaction Details
# 1437   Account History Transaction Details
# 1504   Account History Transaction Details
# 1529   Account History Transaction Details
# 1530   Account History Transaction Details
# 1532   Account History Transaction Details
# 1533   Account History Transaction Details
# 1538   Account History Transaction Details
# 1545   Account History Transaction Details
# 1550   Account History Transaction Details
# 1573   Account History Transaction Details
# 1586   Account History Transaction Details
# 1587   Account History Transaction Details
# 1588   Account History Transaction Details
# 1589   Account History Transaction Details
# 1655   Account History Transaction Details
# 1656   Account History Transaction Details
# 1657   Account History Transaction Details
# 1704   Account History Transaction Details
# 1709   Account History Transaction Details
# 1710   Account History Transaction Details
# 1715   Account History Transaction Details
# 1803   Account History Transaction Details
# 1804   Account History Transaction Details
# 1805   Account History Transaction Details
# 1806   Account History Transaction Details
# 1824   Account History Transaction Details
# 1835   Account History Transaction Details
# 1836   Account History Transaction Details
# 1839   Account History Transaction Details
# 1848   Account History Transaction Details
# 1864   Account History Transaction Details
# 1930   Account History Transaction Details
# 1937   Account History Transaction Details
# 1938   Account History Transaction Details
# 1939   Account History Transaction Details
# 1942   Account History Transaction Details
# 1954   Account History Transaction Details
# 1955   Account History Transaction Details
# 1975   Account History Transaction Details
# 2000   Account History Transaction Details
# 2020   Account History Transaction Details
# 2031   Account History Transaction Details
# 2034   Account History Transaction Details
# 2036   Account History Transaction Details
# 2037   Account History Transaction Details
# 2043   Account History Transaction Details
# 2044   Account History Transaction Details
# 2098   Account History Transaction Details
# 2135   Account History Transaction Details
# 2143   Account History Transaction Details
# 2157   Account History Transaction Details
# 2158   Account History Transaction Details
# 2185   Account History Transaction Details
# 2186   Account History Transaction Details
# 2211   Account History Transaction Details
# 2212   Account History Transaction Details
# 2224   Account History Transaction Details
# 2273   Account History Transaction Details
# 2274   Account History Transaction Details
# 2275   Account History Transaction Details
# 2282   Account History Transaction Details
# 2284   Account History Transaction Details
# 2297   Account History Transaction Details
# 2302   Account History Transaction Details
# 2307   Account History Transaction Details
# 2311   Account History Transaction Details
# 2312   Account History Transaction Details
# 2321   Account History Transaction Details
# 2322   Account History Transaction Details
# 2323   Account History Transaction Details
# 2333   Account History Transaction Details
# 2334   Account History Transaction Details
# 2335   Account History Transaction Details
# 2387   Account History Transaction Details
# 2388   Account History Transaction Details
# 2390   Account History Transaction Details
# 2391   Account History Transaction Details
# 2406   Account History Transaction Details
# 2433   Account History Transaction Details
# 2434   Account History Transaction Details
# 2466   Account History Transaction Details
# 2471   Account History Transaction Details
# 2484   Account History Transaction Details
# 2542   Account History Transaction Details
# 2543   Account History Transaction Details
# 2544   Account History Transaction Details
# 2563   Account History Transaction Details
# 2661   Account History Transaction Details
# 2681   Account History Transaction Details
# 2682   Account History Transaction Details
# 2720   Account History Transaction Details
# 2762   Account History Transaction Details
# 2763   Account History Transaction Details
# 2764   Account History Transaction Details
# 2765   Account History Transaction Details
# 2766   Account History Transaction Details
# 2767   Account History Transaction Details
# 2768   Account History Transaction Details
# 2770   Account History Transaction Details
# 2771   Account History Transaction Details
# 2805   Account History Transaction Details
# 2822   Account History Transaction Details
# 2846   Account History Transaction Details
# 2848   Account History Transaction Details
# 2849   Account History Transaction Details
# 2857   Account History Transaction Details
# 2873   Account History Transaction Details
# 2874   Account History Transaction Details
# 2876   Account History Transaction Details
# 2902   Account History Transaction Details
# 2935   Account History Transaction Details
# 2945   Account History Transaction Details
# 2964   Account History Transaction Details
# 3006   Account History Transaction Details
# 3070   Account History Transaction Details
# 3087   Account History Transaction Details
# 3088   Account History Transaction Details
# 3152   Account History Transaction Details
# 3199   Account History Transaction Details
# 3232   Account History Transaction Details
# 3234   Account History Transaction Details
# 3273   Account History Transaction Details
# 3284   Account History Transaction Details
# 3285   Account History Transaction Details
# 3343   Account History Transaction Details
# 3344   Account History Transaction Details
# 3381   Account History Transaction Details
# 3382   Account History Transaction Details
# 3424   Account History Transaction Details
# 3425   Account History Transaction Details
# 3426   Account History Transaction Details
# 3428   Account History Transaction Details
# 3466   Account History Transaction Details
# 3585   Account History Transaction Details
# 3605   Account History Transaction Details
# 3712   Account History Transaction Details
# 3849   Account History Transaction Details
# 3878   Account History Transaction Details
# 3879   Account History Transaction Details
# 3894   Account History Transaction Details
# 3914   Account History Transaction Details
# 3917   Account History Transaction Details
# 3923   Account History Transaction Details
# 3948   Account History Transaction Details
# 3949   Account History Transaction Details
# 3950   Account History Transaction Details
# 3951   Account History Transaction Details
# 3960   Account History Transaction Details
# 3961   Account History Transaction Details
# 3972   Account History Transaction Details
# 3975   Account History Transaction Details
# 3977   Account History Transaction Details
# 3978   Account History Transaction Details
# 3980   Account History Transaction Details
# 4011   Account History Transaction Details
# 4013   Account History Transaction Details
# 4035   Account History Transaction Details
# 4036   Account History Transaction Details
# 4037   Account History Transaction Details
# 4038   Account History Transaction Details
# 4049   Account History Transaction Details
# 4105   Account History Transaction Details
# 4128   Account History Transaction Details
# 4147   Account History Transaction Details
# 4172   Account History Transaction Details
# 4173   Account History Transaction Details
# 4178   Account History Transaction Details
# 4179   Account History Transaction Details
# 4182   Account History Transaction Details
# 4184   Account History Transaction Details
# 4197   Account History Transaction Details
# 4199   Account History Transaction Details
# 4203   Account History Transaction Details
# 4265   Account History Transaction Details
# 4266   Account History Transaction Details
# 4300   Account History Transaction Details
# 4301   Account History Transaction Details
# 4318   Account History Transaction Details
# 4319   Account History Transaction Details
# 4342   Account History Transaction Details
# 4343   Account History Transaction Details
# 4425   Account History Transaction Details
# 4485   Account History Transaction Details
# 4491   Account History Transaction Details
# 4512   Account History Transaction Details
# 4526   Account History Transaction Details
# 4531   Account History Transaction Details
# 4536   Account History Transaction Details
# 4537   Account History Transaction Details
# 4602   Account History Transaction Details
# 4606   Account History Transaction Details
# 4664   Account History Transaction Details
# 4719   Account History Transaction Details
# 4730   Account History Transaction Details
# 4750   Account History Transaction Details
# 4751   Account History Transaction Details
# 4757   Account History Transaction Details
# 4763   Account History Transaction Details
# 4829   Account History Transaction Details
# 4830   Account History Transaction Details
# 4857   Account History Transaction Details
# 4858   Account History Transaction Details
# 4915   Account History Transaction Details
# 4925   Account History Transaction Details
# 4926   Account History Transaction Details
# 4927   Account History Transaction Details
# 4933   Account History Transaction Details
# 4952   Account History Transaction Details
# 4956   Account History Transaction Details
# 4964   Account History Transaction Details
# 4965   Account History Transaction Details
# 4986   Account History Transaction Details
# 4987   Account History Transaction Details
# 4988   Account History Transaction Details
# 4989   Account History Transaction Details
# 4990   Account History Transaction Details
# 4991   Account History Transaction Details
# 4992   Account History Transaction Details
# 4993   Account History Transaction Details
# 4994   Account History Transaction Details
# 4995   Account History Transaction Details
# 4996   Account History Transaction Details
# 5001   Account History Transaction Details
# 5002   Account History Transaction Details
# 5010   Account History Transaction Details
# 5048   Account History Transaction Details
# 5052   Account History Transaction Details
# 5060   Account History Transaction Details
# 5061   Account History Transaction Details
# 5106   Account History Transaction Details
# 5132   Account History Transaction Details
# 5148   Account History Transaction Details
# 5174   Account History Transaction Details
# 5175   Account History Transaction Details
# 5232   Account History Transaction Details
# 5233   Account History Transaction Details
# 5262   Account History Transaction Details
# 5274   Account History Transaction Details
# 5325   Account History Transaction Details
# 5326   Account History Transaction Details
# 5337   Account History Transaction Details
# 5362   Account History Transaction Details
# 5364   Account History Transaction Details
# 5442   Account History Transaction Details
# 5467   Account History Transaction Details
# 5489   Account History Transaction Details
# 5490   Account History Transaction Details
# 5516   Account History Transaction Details
# 5522   Account History Transaction Details
# 5530   Account History Transaction Details
# 5619   Account History Transaction Details
# 5667   Account History Transaction Details
# 5687   Account History Transaction Details
# 5747   Account History Transaction Details
# 5764   Account History Transaction Details
# 5777   Account History Transaction Details
# 5793   Account History Transaction Details
# 5811   Account History Transaction Details
# 5857   Account History Transaction Details
# 5917   Account History Transaction Details
# 5918   Account History Transaction Details
# 5961   Account History Transaction Details
# 5984   Account History Transaction Details
# 6002   Account History Transaction Details
# 6026   Account History Transaction Details
# 6037   Account History Transaction Details
# 6083   Account History Transaction Details
# 6084   Account History Transaction Details
# 6085   Account History Transaction Details
# 6103   Account History Transaction Details
# 6116   Account History Transaction Details
# 6124   Account History Transaction Details
# 6125   Account History Transaction Details
# 6136   Account History Transaction Details
# 6137   Account History Transaction Details
# 6192   Account History Transaction Details
# 6196   Account History Transaction Details
# 6232   Account History Transaction Details
# 6233   Account History Transaction Details
# 6287   Account History Transaction Details
# 6288   Account History Transaction Details
# 6291   Account History Transaction Details
# 6303   Account History Transaction Details
# 6342   Account History Transaction Details
# 6345   Account History Transaction Details
# 6388   Account History Transaction Details
# 6412   Account History Transaction Details
# 6413   Account History Transaction Details
# 6414   Account History Transaction Details
# 6419   Account History Transaction Details
# 6437   Account History Transaction Details
# 6438   Account History Transaction Details
# 6497   Account History Transaction Details
# 6523   Account History Transaction Details
# 6524   Account History Transaction Details
# 6525   Account History Transaction Details
# 6543   Account History Transaction Details
# 6544   Account History Transaction Details
# 6551   Account History Transaction Details
# 6560   Account History Transaction Details
# 6563   Account History Transaction Details
# 6566   Account History Transaction Details
# 6585   Account History Transaction Details
# 6586   Account History Transaction Details
# 6597   Account History Transaction Details
# 6617   Account History Transaction Details
# 6644   Account History Transaction Details
# 6657   Account History Transaction Details
# 6672   Account History Transaction Details
# 6727   Account History Transaction Details
# 6728   Account History Transaction Details
# 6771   Account History Transaction Details
# 6783   Account History Transaction Details
# 6784   Account History Transaction Details
# 6882   Account History Transaction Details
# 6886   Account History Transaction Details
# 6889   Account History Transaction Details
# 6895   Account History Transaction Details
# 6896   Account History Transaction Details
# 6905   Account History Transaction Details
# 6917   Account History Transaction Details
# 7039   Account History Transaction Details
# 7054   Account History Transaction Details
# 7055   Account History Transaction Details
# 7070   Account History Transaction Details
# 7072   Account History Transaction Details
# 7079   Account History Transaction Details
# 7081   Account History Transaction Details
# 7082   Account History Transaction Details
# 7086   Account History Transaction Details
# 7088   Account History Transaction Details
# 7090   Account History Transaction Details
# 7092   Account History Transaction Details
# 7108   Account History Transaction Details
# 7112   Account History Transaction Details
# 7119   Account History Transaction Details
# 7121   Account History Transaction Details
# 7123   Account History Transaction Details
# 7124   Account History Transaction Details
# 7125   Account History Transaction Details
# 7127   Account History Transaction Details
# 7128   Account History Transaction Details
# 7129   Account History Transaction Details
# 7131   Account History Transaction Details
# 7132   Account History Transaction Details
# 7134   Account History Transaction Details
# 7151   Account History Transaction Details
# 7231   Account History Transaction Details
# 7291   Account History Transaction Details
# 7316   Account History Transaction Details
# 7317   Account History Transaction Details
# 7338   Account History Transaction Details
# 7347   Account History Transaction Details
# 7348   Account History Transaction Details
# 7349   Account History Transaction Details
# 7350   Account History Transaction Details
# 7351   Account History Transaction Details
# 7362   Account History Transaction Details
# 7367   Account History Transaction Details
# 7372   Account History Transaction Details
# 7374   Account History Transaction Details
# 7386   Account History Transaction Details
# 7391   Account History Transaction Details
# 7392   Account History Transaction Details
# 7417   Account History Transaction Details
# 7422   Account History Transaction Details
# 7431   Account History Transaction Details
# 7434   Account History Transaction Details
# 7457   Account History Transaction Details
# 7477   Account History Transaction Details
# 7484   Account History Transaction Details
# 7532   Account History Transaction Details
# 7583   Account History Transaction Details
# 7584   Account History Transaction Details
# 7585   Account History Transaction Details
# 7586   Account History Transaction Details
# 7599   Account History Transaction Details
# 7600   Account History Transaction Details
# 7601   Account History Transaction Details
# 7602   Account History Transaction Details
# 7603   Account History Transaction Details
# 7604   Account History Transaction Details
# 7605   Account History Transaction Details
# 7608   Account History Transaction Details
# 7616   Account History Transaction Details
# 7627   Account History Transaction Details
# 7648   Account History Transaction Details
# 7662   Account History Transaction Details
# 7663   Account History Transaction Details
# 7677   Account History Transaction Details
# 7748   Account History Transaction Details
# 7788   Account History Transaction Details
# 7838   Account History Transaction Details
# 7851   Account History Transaction Details
# 7863   Account History Transaction Details
# 7874   Account History Transaction Details
# 7907   Account History Transaction Details
# 7908   Account History Transaction Details
# 7911   Account History Transaction Details
# 7934   Account History Transaction Details
# 7935   Account History Transaction Details
# 7936   Account History Transaction Details
# 7994   Account History Transaction Details
# 8013   Account History Transaction Details
# 8014   Account History Transaction Details
# 8023   Account History Transaction Details
# 8062   Account History Transaction Details
# 8063   Account History Transaction Details
# 8064   Account History Transaction Details
# 8065   Account History Transaction Details
# 8066   Account History Transaction Details
# 8067   Account History Transaction Details
# 8068   Account History Transaction Details
# 8073   Account History Transaction Details
# 8083   Account History Transaction Details
# 8084   Account History Transaction Details
# 8085   Account History Transaction Details
# 8086   Account History Transaction Details
# 8141   Account History Transaction Details
# 8170   Account History Transaction Details
# 8216   Account History Transaction Details
# 8236   Account History Transaction Details
# 8237   Account History Transaction Details
# 8251   Account History Transaction Details
# 8252   Account History Transaction Details
# 8253   Account History Transaction Details
# 8291   Account History Transaction Details
# 8296   Account History Transaction Details
# 8297   Account History Transaction Details
# 8298   Account History Transaction Details
# 8299   Account History Transaction Details
# 8300   Account History Transaction Details
# 8301   Account History Transaction Details
# 8313   Account History Transaction Details
# 8325   Account History Transaction Details
# 8326   Account History Transaction Details
# 8371   Account History Transaction Details
# 8389   Account History Transaction Details
# 8410   Account History Transaction Details
# 8438   Account History Transaction Details
# 8439   Account History Transaction Details
# 8440   Account History Transaction Details
# 8441   Account History Transaction Details
# 8442   Account History Transaction Details
# 8453   Account History Transaction Details
# 8458   Account History Transaction Details
# 8459   Account History Transaction Details
# 8460   Account History Transaction Details
# 8462   Account History Transaction Details
# 8463   Account History Transaction Details
# 8469   Account History Transaction Details
# 8537   Account History Transaction Details
# 8577   Account History Transaction Details
# 8578   Account History Transaction Details
# 8579   Account History Transaction Details
# 8581   Account History Transaction Details
# 8582   Account History Transaction Details
# 8584   Account History Transaction Details
# 8591   Account History Transaction Details
# 8592   Account History Transaction Details
# 8593   Account History Transaction Details
# 8595   Account History Transaction Details
# 8596   Account History Transaction Details
# 8597   Account History Transaction Details
# 8598   Account History Transaction Details
# 8611   Account History Transaction Details
# 8616   Account History Transaction Details
# 8662   Account History Transaction Details
# 8670   Account History Transaction Details
# 8683   Account History Transaction Details
# 8693   Account History Transaction Details
# 8694   Account History Transaction Details
# 8696   Account History Transaction Details
# 8697   Account History Transaction Details
# 8698   Account History Transaction Details
# 8699   Account History Transaction Details
# 8703   Account History Transaction Details
# 8714   Account History Transaction Details
# 8723   Account History Transaction Details
# 8817   Account History Transaction Details
# 8822   Account History Transaction Details
# 8823   Account History Transaction Details
# 8825   Account History Transaction Details
# 8826   Account History Transaction Details
# 8827   Account History Transaction Details
# 8828   Account History Transaction Details
# 8829   Account History Transaction Details
# 8850   Account History Transaction Details
# 8852   Account History Transaction Details
# 8854   Account History Transaction Details
# 8855   Account History Transaction Details
# 8856   Account History Transaction Details
# 8859   Account History Transaction Details
# 8876   Account History Transaction Details
# 8894   Account History Transaction Details
# 8897   Account History Transaction Details
# 8930   Account History Transaction Details
# 8935   Account History Transaction Details
# 8944   Account History Transaction Details
# 8965   Account History Transaction Details
# 8966   Account History Transaction Details
# 8968   Account History Transaction Details
# 8977   Account History Transaction Details
# 8984   Account History Transaction Details
# 8985   Account History Transaction Details
# 8998   Account History Transaction Details
# 9009   Account History Transaction Details
# 9054   Account History Transaction Details
# 9077   Account History Transaction Details
# 9078   Account History Transaction Details
# 9079   Account History Transaction Details
# 9080   Account History Transaction Details
# 9083   Account History Transaction Details
# 9114   Account History Transaction Details
# 9115   Account History Transaction Details
# 9124   Account History Transaction Details
# 9177   Account History Transaction Details
# 9178   Account History Transaction Details
# 9220   Account History Transaction Details
# 9253   Account History Transaction Details
# 9254   Account History Transaction Details
# 9320   Account History Transaction Details
# 9371   Account History Transaction Details
# 9385   Account History Transaction Details
# 9386   Account History Transaction Details
# 9387   Account History Transaction Details
# 9398   Account History Transaction Details
# 9418   Account History Transaction Details
# 9419   Account History Transaction Details
# 9421   Account History Transaction Details
# 9431   Account History Transaction Details
# 9517   Account History Transaction Details
# 9518   Account History Transaction Details
# 9519   Account History Transaction Details
# 9553   Account History Transaction Details
# 9559   Account History Transaction Details
# 9568   Account History Transaction Details
# 9569   Account History Transaction Details
# 9570   Account History Transaction Details
# 9573   Account History Transaction Details
# 9631   Account History Transaction Details
# 9650   Account History Transaction Details
# 9663   Account History Transaction Details
# 9691   Account History Transaction Details
# 9704   Account History Transaction Details
# 9716   Account History Transaction Details
# 9718   Account History Transaction Details
# 9723   Account History Transaction Details
# 9753   Account History Transaction Details
# 9788   Account History Transaction Details
# 9789   Account History Transaction Details
# 9798   Account History Transaction Details
# 9826   Account History Transaction Details
# 9829   Account History Transaction Details
# 9830   Account History Transaction Details
# 9833   Account History Transaction Details
# 9893   Account History Transaction Details
# 9894   Account History Transaction Details
# 9895   Account History Transaction Details
# 9915   Account History Transaction Details
# 9935   Account History Transaction Details
# 9980   Account History Transaction Details
# 9986   Account History Transaction Details
# 9987   Account History Transaction Details
# 9988   Account History Transaction Details
# 9993   Account History Transaction Details
# 10011  Account History Transaction Details
# 10028  Account History Transaction Details
# 10029  Account History Transaction Details
# 10047  Account History Transaction Details
# 10059  Account History Transaction Details
# 10133  Account History Transaction Details
# 10187  Account History Transaction Details
# 10211  Account History Transaction Details
# 10220  Account History Transaction Details
# 10221  Account History Transaction Details
# 10243  Account History Transaction Details
# 10256  Account History Transaction Details
# 10279  Account History Transaction Details
# 10292  Account History Transaction Details
# 10294  Account History Transaction Details
# 10296  Account History Transaction Details
# 10301  Account History Transaction Details
# 10346  Account History Transaction Details
# 10375  Account History Transaction Details
# 10377  Account History Transaction Details
# 10378  Account History Transaction Details
# 10399  Account History Transaction Details
# 10402  Account History Transaction Details
# 10412  Account History Transaction Details
# 10447  Account History Transaction Details
# 10454  Account History Transaction Details
# 10462  Account History Transaction Details
# 10465  Account History Transaction Details
# 10499  Account History Transaction Details
# 10513  Account History Transaction Details
# 10544  Account History Transaction Details
# 10560  Account History Transaction Details
# 10576  Account History Transaction Details
# 10580  Account History Transaction Details
# 10588  Account History Transaction Details
# 10621  Account History Transaction Details
# 10642  Account History Transaction Details
# 10668  Account History Transaction Details
# 10678  Account History Transaction Details
# 10679  Account History Transaction Details
# 10697  Account History Transaction Details
# 10709  Account History Transaction Details
# 10715  Account History Transaction Details
# 10800  Account History Transaction Details
# 10834  Account History Transaction Details
# 10877  Account History Transaction Details
# 10884  Account History Transaction Details
# 10887  Account History Transaction Details
# 10898  Account History Transaction Details
# 10899  Account History Transaction Details
# 10909  Account History Transaction Details
# 10910  Account History Transaction Details
# 10930  Account History Transaction Details
# 10935  Account History Transaction Details
# 10936  Account History Transaction Details
# 10956  Account History Transaction Details
# 10965  Account History Transaction Details
# 10966  Account History Transaction Details
# 10967  Account History Transaction Details
# 11046  Account History Transaction Details
# 11072  Account History Transaction Details
# 11083  Account History Transaction Details
# 11084  Account History Transaction Details
# 11085  Account History Transaction Details
# 11086  Account History Transaction Details
# 11087  Account History Transaction Details
# 11088  Account History Transaction Details
# 11092  Account History Transaction Details
# 11214  Account History Transaction Details
# 11215  Account History Transaction Details
# 11254  Account History Transaction Details
# 11327  Account History Transaction Details
# 11354  Account History Transaction Details
# 11359  Account History Transaction Details
# 11445  Account History Transaction Details
# 11481  Account History Transaction Details
# 11489  Account History Transaction Details
# 11491  Account History Transaction Details
# 11568  Account History Transaction Details
# 11569  Account History Transaction Details
# 11608  Account History Transaction Details
# 11619  Account History Transaction Details
# 11677  Account History Transaction Details
# 11678  Account History Transaction Details
# 11679  Account History Transaction Details
# 11680  Account History Transaction Details
# 11681  Account History Transaction Details
# 11683  Account History Transaction Details
# 11684  Account History Transaction Details
# 11693  Account History Transaction Details
# 11694  Account History Transaction Details
# 11750  Account History Transaction Details
# 11753  Account History Transaction Details
# 11821  Account History Transaction Details
# 11856  Account History Transaction Details
# 11857  Account History Transaction Details
# 11872  Account History Transaction Details
# 11877  Account History Transaction Details
# 11879  Account History Transaction Details
# 11880  Account History Transaction Details
# 11916  Account History Transaction Details
# 11918  Account History Transaction Details
# 11919  Account History Transaction Details
# 11945  Account History Transaction Details
# 12058  Account History Transaction Details
# 12065  Account History Transaction Details
# 12067  Account History Transaction Details
# 12082  Account History Transaction Details
# 12083  Account History Transaction Details
# 12104  Account History Transaction Details
# 12105  Account History Transaction Details
# 12106  Account History Transaction Details
# 12114  Account History Transaction Details
# 12134  Account History Transaction Details
# 12153  Account History Transaction Details
# 12233  Account History Transaction Details
# 12239  Account History Transaction Details
# 12244  Account History Transaction Details
# 12245  Account History Transaction Details
# 12246  Account History Transaction Details
# 12247  Account History Transaction Details
# 12251  Account History Transaction Details
# 12258  Account History Transaction Details
# 12271  Account History Transaction Details
# 12391  Account History Transaction Details
# 12405  Account History Transaction Details
# 12406  Account History Transaction Details
# 12433  Account History Transaction Details
# 12453  Account History Transaction Details
# 12454  Account History Transaction Details
# 12460  Account History Transaction Details
# 12534  Account History Transaction Details
# 12570  Account History Transaction Details
# 12571  Account History Transaction Details
# 12585  Account History Transaction Details
# 12613  Account History Transaction Details
# 12634  Account History Transaction Details
# 12635  Account History Transaction Details
# 12640  Account History Transaction Details
# 12641  Account History Transaction Details
# 12694  Account History Transaction Details
# 12695  Account History Transaction Details
# 12696  Account History Transaction Details
# 12702  Account History Transaction Details
# 12704  Account History Transaction Details
# 12755  Account History Transaction Details
# 12759  Account History Transaction Details
# 12762  Account History Transaction Details
# 12769  Account History Transaction Details
# 12800  Account History Transaction Details
# 12803  Account History Transaction Details
# 12804  Account History Transaction Details
# 12807  Account History Transaction Details
# 12812  Account History Transaction Details
# 12847  Account History Transaction Details
# 12862  Account History Transaction Details
# 12916  Account History Transaction Details
# 12938  Account History Transaction Details
# 12946  Account History Transaction Details
# 12973  Account History Transaction Details
# 13052  Account History Transaction Details
# 13067  Account History Transaction Details
# 13070  Account History Transaction Details
# 13133  Account History Transaction Details
# 13180  Account History Transaction Details
# 13181  Account History Transaction Details
# 13194  Account History Transaction Details
# 13195  Account History Transaction Details
# 13260  Account History Transaction Details
# 13269  Account History Transaction Details
# 13274  Account History Transaction Details
# 13292  Account History Transaction Details
# 13293  Account History Transaction Details
# 13337  Account History Transaction Details
# 13338  Account History Transaction Details
# 13339  Account History Transaction Details
# 13340  Account History Transaction Details
# 13341  Account History Transaction Details
# 13342  Account History Transaction Details
# 13343  Account History Transaction Details
# 13344  Account History Transaction Details
# 13345  Account History Transaction Details
# 13346  Account History Transaction Details
# 13347  Account History Transaction Details
# 13348  Account History Transaction Details
# 13349  Account History Transaction Details
# 13350  Account History Transaction Details
# 13351  Account History Transaction Details
# 13352  Account History Transaction Details
# 13353  Account History Transaction Details
# 13354  Account History Transaction Details
# 13355  Account History Transaction Details
# 13356  Account History Transaction Details
# 13357  Account History Transaction Details
# 13358  Account History Transaction Details
# 13359  Account History Transaction Details
# 13372  Account History Transaction Details
# 13373  Account History Transaction Details
# 13379  Account History Transaction Details
# 13380  Account History Transaction Details
# 13381  Account History Transaction Details
# 13387  Account History Transaction Details
# 13405  Account History Transaction Details
# 13406  Account History Transaction Details
# 13408  Account History Transaction Details
# 13414  Account History Transaction Details
# 13424  Account History Transaction Details
# 13425  Account History Transaction Details
# 13426  Account History Transaction Details
# 13436  Account History Transaction Details
# 13547  Account History Transaction Details
# 13583  Account History Transaction Details
# 13586  Account History Transaction Details
# 13601  Account History Transaction Details
# 13633  Account History Transaction Details
# 13634  Account History Transaction Details
# 13639  Account History Transaction Details
# 13654  Account History Transaction Details
# 13693  Account History Transaction Details
# 13694  Account History Transaction Details
# 13696  Account History Transaction Details
# 13770  Account History Transaction Details
# 13771  Account History Transaction Details
# 13774  Account History Transaction Details
# 13777  Account History Transaction Details
# 13818  Account History Transaction Details
# 13819  Account History Transaction Details
# 13820  Account History Transaction Details
# 13826  Account History Transaction Details
# 13829  Account History Transaction Details
# 13830  Account History Transaction Details
# 13831  Account History Transaction Details
# 13832  Account History Transaction Details
# 13833  Account History Transaction Details
# 13835  Account History Transaction Details
# 13838  Account History Transaction Details
# 13860  Account History Transaction Details
# 13885  Account History Transaction Details
# 13886  Account History Transaction Details
# 13887  Account History Transaction Details
# 13888  Account History Transaction Details
# 13892  Account History Transaction Details
# 13893  Account History Transaction Details
# 13895  Account History Transaction Details
# 13898  Account History Transaction Details
# 13899  Account History Transaction Details
# 13923  Account History Transaction Details
# 13978  Account History Transaction Details
# 13983  Account History Transaction Details
# 13988  Account History Transaction Details
# 13990  Account History Transaction Details
# 14044  Account History Transaction Details
# 14045  Account History Transaction Details
# 14046  Account History Transaction Details
# 14060  Account History Transaction Details
# 14061  Account History Transaction Details
# 14089  Account History Transaction Details
# 14091  Account History Transaction Details
# 14127  Account History Transaction Details
# 14224  Account History Transaction Details
# 14225  Account History Transaction Details
# 14267  Account History Transaction Details
# 14281  Account History Transaction Details
# 14320  Account History Transaction Details
# 14358  Account History Transaction Details
# 14359  Account History Transaction Details
# 14374  Account History Transaction Details
# 14378  Account History Transaction Details
# 14409  Account History Transaction Details
# 14411  Account History Transaction Details
# 14412  Account History Transaction Details
# 14427  Account History Transaction Details
# 14432  Account History Transaction Details
# 14447  Account History Transaction Details
# 14515  Account History Transaction Details
# 14520  Account History Transaction Details
# 14554  Account History Transaction Details
# 14557  Account History Transaction Details
# 14563  Account History Transaction Details
# 14565  Account History Transaction Details
# 14566  Account History Transaction Details
# 14590  Account History Transaction Details
# 14630  Account History Transaction Details
# 14635  Account History Transaction Details
# 14643  Account History Transaction Details
# 14652  Account History Transaction Details
# 14700  Account History Transaction Details
# 14761  Account History Transaction Details
# 14814  Account History Transaction Details
# 14816  Account History Transaction Details
# 14833  Account History Transaction Details
# 14847  Account History Transaction Details
# 14858  Account History Transaction Details
# 14868  Account History Transaction Details
# 14877  Account History Transaction Details
# 14889  Account History Transaction Details
# 14891  Account History Transaction Details
# 14893  Account History Transaction Details
# 14894  Account History Transaction Details
# 14895  Account History Transaction Details
# 14918  Account History Transaction Details
# 14925  Account History Transaction Details
# 14967  Account History Transaction Details
# 14980  Account History Transaction Details
# 14992  Account History Transaction Details
# 14993  Account History Transaction Details
# 14994  Account History Transaction Details
# 15060  Account History Transaction Details
# 15061  Account History Transaction Details
# 15126  Account History Transaction Details
# 15131  Account History Transaction Details
# 15134  Account History Transaction Details
# 15135  Account History Transaction Details
# 15136  Account History Transaction Details
# 15142  Account History Transaction Details
# 15171  Account History Transaction Details
# 15206  Account History Transaction Details
# 15218  Account History Transaction Details
# 15234  Account History Transaction Details
# 15248  Account History Transaction Details
# 15255  Account History Transaction Details
# 15319  Account History Transaction Details
# 15375  Account History Transaction Details
# 15378  Account History Transaction Details
# 15417  Account History Transaction Details
# 15429  Account History Transaction Details
# 15433  Account History Transaction Details
# 15434  Account History Transaction Details
# 15447  Account History Transaction Details
# 15491  Account History Transaction Details
# 15499  Account History Transaction Details
# 15504  Account History Transaction Details
# 15505  Account History Transaction Details
# 15506  Account History Transaction Details
# 15507  Account History Transaction Details
# 15546  Account History Transaction Details
# 15564  Account History Transaction Details
# 15581  Account History Transaction Details
# 15582  Account History Transaction Details
# 15609  Account History Transaction Details
# 15610  Account History Transaction Details
# 15612  Account History Transaction Details
# 15614  Account History Transaction Details
# 15626  Account History Transaction Details
# 15627  Account History Transaction Details
# 15721  Account History Transaction Details
# 15722  Account History Transaction Details
# 15723  Account History Transaction Details
# 15724  Account History Transaction Details
# 15725  Account History Transaction Details
# 15733  Account History Transaction Details
# 15738  Account History Transaction Details
# 15749  Account History Transaction Details
# 15751  Account History Transaction Details
# 15765  Account History Transaction Details
# 15776  Account History Transaction Details
# 15781  Account History Transaction Details
# 15863  Account History Transaction Details
# 15877  Account History Transaction Details
# 15889  Account History Transaction Details
# 15902  Account History Transaction Details
# 15903  Account History Transaction Details
# 15912  Account History Transaction Details
# 15913  Account History Transaction Details
# 15921  Account History Transaction Details
# 15928  Account History Transaction Details
# 15937  Account History Transaction Details
# 15962  Account History Transaction Details
# 15963  Account History Transaction Details
# 15970  Account History Transaction Details
# 15980  Account History Transaction Details
# 15982  Account History Transaction Details
# 15983  Account History Transaction Details
# 15984  Account History Transaction Details
# 15985  Account History Transaction Details
# 15986  Account History Transaction Details
# 15987  Account History Transaction Details
# 16018  Account History Transaction Details
# 16062  Account History Transaction Details
# 16088  Account History Transaction Details
# 16092  Account History Transaction Details
# 16103  Account History Transaction Details
# 16144  Account History Transaction Details
# 16182  Account History Transaction Details
# 16187  Account History Transaction Details
# 16201  Account History Transaction Details
# 16234  Account History Transaction Details
# 16235  Account History Transaction Details
# 16237  Account History Transaction Details
# 16262  Account History Transaction Details
# 16309  Account History Transaction Details
# 16312  Account History Transaction Details
# 16317  Account History Transaction Details
# 16381  Account History Transaction Details
# 16387  Account History Transaction Details
# 16423  Account History Transaction Details
# 16425  Account History Transaction Details
# 16457  Account History Transaction Details
# 16466  Account History Transaction Details
# ...
# 21063                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21092     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21106  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21168     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21170     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21209                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21223     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21240  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21335                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21336  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21348     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21367           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 21368           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 21372                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21375  {"Type":"Pro Plan Subscription","Status":"Overdue","Navigated From":"account_history"}
# 21376  {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Overdue"}
# 21379     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21382     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21384                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21385  {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Overdue"}
# 21387                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21388                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 21389     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21392  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21434                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21436                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21439                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21490                  {"Navigated From":"Account History","Status":"Overdue","Type":"Order"}
# 21557     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21559           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 21571     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21572           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 21573           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 21574                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 21575     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21576                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 21623     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21624     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21625                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 21626     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 21630     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 21632     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 21633     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21639                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21653     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 21663                        {"Type":"Refund Transaction","Navigated From":"account_history"}
# 21691                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 21692  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21693  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 21744     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21762     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21763     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21764     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 21765                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21835                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 21874                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 21875                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 21897                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 21898                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21903                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21905                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 21906                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21907     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 21912                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 21975     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 22013                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22014                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22015     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22018                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22019                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22102     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22128                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 22140                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22141     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22142     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22198                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22199                            {"Type":"Manual Payment","Navigated From":"account_history"}
# 22200                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 22201                            {"Type":"Manual Payment","Navigated From":"account_history"}
# 22236                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22396                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 22397     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22398           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22402     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22403     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22413     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22419  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 22449                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 22450                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 22451                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 22469                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 22582     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22586                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22594                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22595     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22610     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22615     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22617  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 22627           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22631                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22633                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 22634     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22646                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22648                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22649                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22650     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22653     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22654     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22655     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22662                        {"Type":"Refund Transaction","Navigated From":"account_history"}
# 22678                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 22679     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22711                        {"Type":"Refund Transaction","Navigated From":"account_history"}
# 22718                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22737     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22740                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 22741     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 22742     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22743     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22744                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 22784           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22828  {"Type":"Violation Transaction","Status":"Overdue","Navigated From":"account_history"}
# 22829  {"Type":"Violation Transaction","Navigated From":"account_history","Status":"Overdue"}
# 22842           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22844     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 22855     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 22886           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22911     {"Type":"Pro Plan Subscription","Status":"Paid","Navigated From":"account_history"}
# 22912                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 22938                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 22969           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22970           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 22985                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 22987     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22989     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 22997                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 22998                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 22999                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23029                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23030                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23050                              {"Type":"Auto Payment","Navigated From":"account_history"}
# 23072           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 23073     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 23074                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23075                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23111                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23112                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 23113                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23114                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23115                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23148                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23149                     {"Type":"Order","Status":"Paid","Navigated From":"account_history"}
# 23154                     {"Type":"Order","Navigated From":"account_history","Status":"Paid"}
# 23264                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23268                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23274     {"Type":"Pro Plan Subscription","Navigated From":"account_history","Status":"Paid"}
# 23275                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 23276                            {"Type":"Forced Payment","Navigated From":"account_history"}
# 23282           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 23291  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 23292  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 23293  {"Navigated From":"Account History","Status":"Pending","Type":"Violation Transaction"}
# 23322                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23323                     {"Navigated From":"Account History","Status":"Paid","Type":"Order"}
# 23324           {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 23348     {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}

# %%
data_filtered[data_filtered.event_name.str.contains('Chat Conversation')][["userid","event_name", "event_attributes"]].head(50)
# looks like Chat Conversation Started always follows Opened
# Out:
#                                 userid                 event_name  \
# 37    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 40    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 41    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 42    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 43    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 44    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 45    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 46    017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 76    017f4557810b3ba165d2959c17b916b6  Chat Conversation Started
# 109   ddfd6a4298e15df738efd4daa76403e4   Chat Conversation Opened
# 110   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 111   ddfd6a4298e15df738efd4daa76403e4   Chat Conversation Opened
# 112   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 113   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 142   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 143   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 144   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 145   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 209   017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 225   ddfd6a4298e15df738efd4daa76403e4  Chat Conversation Started
# 283   017f4557810b3ba165d2959c17b916b6   Chat Conversation Opened
# 396   ed9415f4732f014b921f23399bec442b   Chat Conversation Opened
# 397   ed9415f4732f014b921f23399bec442b  Chat Conversation Started
# 418   ed9415f4732f014b921f23399bec442b  Chat Conversation Started
# 514   430d96d025d9c30dbd62aa4fd3591e98   Chat Conversation Opened
# 515   430d96d025d9c30dbd62aa4fd3591e98  Chat Conversation Started
# 518   430d96d025d9c30dbd62aa4fd3591e98   Chat Conversation Opened
# 545   73a754cf72593344bcd2412c1c24975b   Chat Conversation Opened
# 571   02697c4704fe66dad2b28c0e14499911  Chat Conversation Started
# 584   79bcd342e50f3d187104aa2849b51375   Chat Conversation Opened
# 585   79bcd342e50f3d187104aa2849b51375  Chat Conversation Started
# 586   79bcd342e50f3d187104aa2849b51375   Chat Conversation Opened
# 617   8e41dac4313f80f2dd619b3de9159a28  Chat Conversation Started
# 618   8e41dac4313f80f2dd619b3de9159a28  Chat Conversation Started
# 870   845035ae3fc96723b46369623ec6ba51   Chat Conversation Opened
# 883   1c5d42f9cf94d9eca90b3628d4d7f75d   Chat Conversation Opened
# 884   1c5d42f9cf94d9eca90b3628d4d7f75d  Chat Conversation Started
# 925   12746b8d8cd1a53826ca718d8e3f0e2d   Chat Conversation Opened
# 926   12746b8d8cd1a53826ca718d8e3f0e2d  Chat Conversation Started
# 1061  520c53e60a665c9c1c78671024f640a7   Chat Conversation Opened
# 1062  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1063  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1064  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1065  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1066  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1067  520c53e60a665c9c1c78671024f640a7  Chat Conversation Started
# 1189  410ff2f2d9e4f17566eeee53bed279fd   Chat Conversation Opened
# 1190  410ff2f2d9e4f17566eeee53bed279fd  Chat Conversation Started
# 1195  410ff2f2d9e4f17566eeee53bed279fd   Chat Conversation Opened
# 1226  410ff2f2d9e4f17566eeee53bed279fd   Chat Conversation Opened
#
#                                                      event_attributes
# 37                                                    {"From":"Menu"}
# 40                                                    {"From":"Menu"}
# 41                                                    {"From":"Menu"}
# 42                                                    {"From":"Menu"}
# 43                                                    {"From":"Menu"}
# 44                                                    {"From":"Menu"}
# 45                                                    {"From":"Menu"}
# 46                                                    {"From":"Menu"}
# 76                                                                 {}
# 109                             {"From":"Menu","Transaction type":""}
# 110                                                                {}
# 111                             {"From":"Menu","Transaction type":""}
# 112                                                                {}
# 113                                                                {}
# 142                                                                {}
# 143                                                                {}
# 144                                                                {}
# 145                                                                {}
# 209                                                   {"From":"Menu"}
# 225                                                                {}
# 283                                                   {"From":"Menu"}
# 396                             {"From":"Menu","Transaction type":""}
# 397                                                                {}
# 418                                                                {}
# 514                                                   {"From":"Menu"}
# 515                                                                {}
# 518                                                   {"From":"Menu"}
# 545                                                   {"From":"Menu"}
# 571                                                                {}
# 584   {"Transaction type":"AutoPayment","From":"Transaction Details"}
# 585                                                                {}
# 586                                                   {"From":"Menu"}
# 617                                                                {}
# 618                                                                {}
# 870   {"Transaction type":"AutoPayment","From":"Transaction Details"}
# 883   {"From":"Transaction Details","Transaction type":"AutoPayment"}
# 884                                                                {}
# 925   {"Transaction type":"AutoPayment","From":"Transaction Details"}
# 926                                                                {}
# 1061                            {"From":"Menu","Transaction type":""}
# 1062                                                               {}
# 1063                                                               {}
# 1064                                                               {}
# 1065                                                               {}
# 1066                                                               {}
# 1067                                                               {}
# 1189                                                  {"From":"Menu"}
# 1190                                                               {}
# 1195                                                  {"From":"Menu"}
# 1226                                                  {"From":"Menu"}

# %%
# event history of some user
data_filtered[data_filtered.userid == "520c53e60a665c9c1c78671024f640a7"]
# Out:
#                                  userid user_state  \
# 1014   520c53e60a665c9c1c78671024f640a7         TX
# 1015   520c53e60a665c9c1c78671024f640a7         TX
# 1016   520c53e60a665c9c1c78671024f640a7         TX
# 1058   520c53e60a665c9c1c78671024f640a7         TX
# 1059   520c53e60a665c9c1c78671024f640a7         TX
# 1060   520c53e60a665c9c1c78671024f640a7         TX
# 1061   520c53e60a665c9c1c78671024f640a7         TX
# 1062   520c53e60a665c9c1c78671024f640a7         TX
# 1063   520c53e60a665c9c1c78671024f640a7         TX
# 1064   520c53e60a665c9c1c78671024f640a7         TX
# 1065   520c53e60a665c9c1c78671024f640a7         TX
# 1066   520c53e60a665c9c1c78671024f640a7         TX
# 1067   520c53e60a665c9c1c78671024f640a7         TX
# 6937   520c53e60a665c9c1c78671024f640a7         TX
# 7627   520c53e60a665c9c1c78671024f640a7         TX
# 7628   520c53e60a665c9c1c78671024f640a7         TX
# 9184   520c53e60a665c9c1c78671024f640a7         TX
# 19733  520c53e60a665c9c1c78671024f640a7         TX
#
#                                 event_name  \
# 1014                       Sign Up Success
# 1015            Add Payment Method Success
# 1016                  Subscription Premium
# 1058   Account History Transaction Details
# 1059                         Wallet Opened
# 1060                       Calculator View
# 1061              Chat Conversation Opened
# 1062             Chat Conversation Started
# 1063             Chat Conversation Started
# 1064             Chat Conversation Started
# 1065             Chat Conversation Started
# 1066             Chat Conversation Started
# 1067             Chat Conversation Started
# 6937            Subscription Premium Renew
# 7627   Account History Transaction Details
# 7628                         Wallet Opened
# 9184                              Sign Out
# 19733                                Order
#
#                                                                           event_attributes  \
# 1014                                                                   {"Method":"Google"}
# 1015                              {"Payment Method":"Credit","Tokenized Pay":"Google Pay"}
# 1016   {"Start Date":"2022-01-20","Renewal Date":"2022-02-21","Membership Type":"Monthly"}
# 1058         {"Navigated From":"Account History","Status":"Pending","Type":"Auto Payment"}
# 1059                                                                                    {}
# 1060                                                                                    {}
# 1061                                                 {"From":"Menu","Transaction type":""}
# 1062                                                                                    {}
# 1063                                                                                    {}
# 1064                                                                                    {}
# 1065                                                                                    {}
# 1066                                                                                    {}
# 1067                                                                                    {}
# 6937    {"Start Date":"2022-02-21","Renewal Date":"2023-02-21","Membership Type":"Yearly"}
# 7627   {"Navigated From":"Account History","Status":"Paid","Type":"Pro Plan Subscription"}
# 7628                                                                                    {}
# 9184                                                                     {"Type":"Manual"}
# 19733                                                        {"Premium Membership":"True"}
#
#        event_created_date event_platform device_manufacture device_model  \
# 1014  2022-01-20 19:27:15        android            samsung     SM-N985F
# 1015  2022-01-20 19:36:42        android            samsung     SM-N985F
# 1016  2022-01-20 19:37:26      outofband                NaN          NaN
# 1058  2022-01-21 01:48:19        android            samsung     SM-N985F
# 1059  2022-01-21 01:49:44        android            samsung     SM-N985F
# 1060  2022-01-21 01:52:14        android            samsung     SM-N985F
# 1061  2022-01-21 01:53:06        android            samsung     SM-N985F
# 1062  2022-01-21 01:53:06        android            samsung     SM-N985F
# 1063  2022-01-21 01:54:21        android            samsung     SM-N985F
# 1064  2022-01-21 01:57:21        android            samsung     SM-N985F
# 1065  2022-01-21 02:00:54        android            samsung     SM-N985F
# 1066  2022-01-21 02:02:59        android            samsung     SM-N985F
# 1067  2022-01-21 02:16:31        android            samsung     SM-N985F
# 6937  2022-02-20 01:07:44      outofband                NaN          NaN
# 7627  2022-02-23 00:18:24        android            samsung     SM-N985F
# 7628  2022-02-23 00:18:55        android            samsung     SM-N985F
# 9184  2022-02-27 09:26:03        android            samsung     SM-N985F
# 19733 2022-04-05 06:02:49      outofband                NaN          NaN
#
#                                                                              event_attributes_d
# 1014                                                                       {'Method': 'Google'}
# 1015                                {'Payment Method': 'Credit', 'Tokenized Pay': 'Google Pay'}
# 1016   {'Start Date': '2022-01-20', 'Renewal Date': '2022-02-21', 'Membership Type': 'Monthly'}
# 1058         {'Navigated From': 'Account History', 'Status': 'Pending', 'Type': 'Auto Payment'}
# 1059                                                                                         {}
# 1060                                                                                         {}
# 1061                                                   {'From': 'Menu', 'Transaction type': ''}
# 1062                                                                                         {}
# 1063                                                                                         {}
# 1064                                                                                         {}
# 1065                                                                                         {}
# 1066                                                                                         {}
# 1067                                                                                         {}
# 6937    {'Start Date': '2022-02-21', 'Renewal Date': '2023-02-21', 'Membership Type': 'Yearly'}
# 7627   {'Navigated From': 'Account History', 'Status': 'Paid', 'Type': 'Pro Plan Subscription'}
# 7628                                                                                         {}
# 9184                                                                         {'Type': 'Manual'}
# 19733                                                            {'Premium Membership': 'True'}

# %% [markdown]
# Let's look on event attributes for several events types

# %%
data_filtered[data_filtered.event_name.str.contains('Chat Conversation Started')][["event_name", "event_attributes"]].event_attributes.unique()
# Out:
# array(['{}'], dtype=object)

# %%
data_filtered[data_filtered.event_name.str.contains('Chat Conversation Opened')][["event_name", "event_attributes"]].event_attributes.unique()
# Out:
# array(['{"From":"Menu"}', '{"From":"Menu","Transaction type":""}',
#        '{"Transaction type":"AutoPayment","From":"Transaction Details"}',
#        '{"From":"Transaction Details","Transaction type":"AutoPayment"}',
#        '{"From":"Transaction Details","Transaction type":"Pro Plan Subscription"}',
#        '{}',
#        '{"Transaction type":"ManualPayment","From":"Transaction Details"}',
#        '{"From":"Transaction Details","Transaction type":"OrderPayment"}',
#        '{"Transaction type":"OrderAlert","From":"Transaction Details"}',
#        '{"Transaction type":"Pro Plan Subscription","From":"Transaction Details"}',
#        '{"From":"Deeplink"}',
#        '{"From":"Transaction Details","Transaction type":"OrderAlert"}',
#        '{"From":"Transaction Details","Transaction Type":"Pro Plan Subscription"}',
#        '{"From":"Deeplink","Transaction type":""}',
#        '{"From":"","Transaction type":""}',
#        '{"Transaction type":"OrderPayment","From":"Transaction Details"}',
#        '{"Transaction type":"ForcedPayment","From":"Transaction Details"}',
#        '{"From":"Dashboard"}',
#        '{"From":"Dashboard","Transaction type":""}'], dtype=object)

# %%
len(data_filtered[data_filtered.event_name.str.contains('Chat Conversation Opened')]), len(data_filtered[data_filtered.event_name.str.contains('Chat Conversation Started')])
# Out:
# (1121, 894)

# %%
data_filtered[data_filtered.event_name.str.contains('Add Payment Method Success')][["event_name", "event_attributes"]].event_attributes.unique()
# Out:
# array(['{"Tokenized Pay":"Apple Pay","Payment Method":"Debit"}',
#        '{"Payment Method":"Debit"}',
#        '{"Payment Method":"PayPal","Tokenized Pay":""}',
#        '{"Payment Method":"Credit","Tokenized Pay":"Google Pay"}',
#        '{"Payment Method":"Debit","Tokenized Pay":""}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Credit"}',
#        '{"Payment Method":"Venmo"}', '{"Payment Method":"PayPal"}',
#        '{"Payment Method":"Debit","Tokenized Pay":"Google Pay"}',
#        '{"Payment Method":"Credit"}',
#        '{"Payment Method":"Credit","Tokenized Pay":""}',
#        '{"Payment Method":"Debit","Tokenized Pay":"Google Pay","Promo code":""}',
#        '{"Payment Method":"Debit","Tokenized Pay":"","Promo code":""}',
#        '{"Payment Method":"Debit","Promo code":""}',
#        '{"Payment Method":"Credit","Promo code":""}',
#        '{"Payment Method":"PayPal","Tokenized Pay":"","Promo code":""}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Debit","Promo code":""}',
#        '{"Payment Method":"Credit","Tokenized Pay":"","Promo code":""}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Credit","Promo code":""}',
#        '{"Payment Method":"PayPal","Tokenized Pay":"","Promo code":"GRIDWISE"}',
#        '{"Payment Method":"PayPal","Promo code":""}',
#        '{"Payment Method":"Debit","Promo code":"GRIDWISE"}',
#        '{"Payment Method":"Venmo","Promo code":""}',
#        '{"Payment Method":"PayPal","Promo code":"INFLUENCER2021"}',
#        '{"Payment Method":"Venmo","Promo code":"INFLUENCER2021"}',
#        '{"Payment Method":"Debit","Promo code":"INFLUENCER2021"}',
#        '{"Payment Method":"Credit","Tokenized Pay":"Google Pay","Promo code":""}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Debit","Promo code":"LUCKYDAY"}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Credit","Promo code":"GRIDWISE"}',
#        '{"Payment Method":"Debit","Tokenized Pay":"","Promo code":"GRIDWISE"}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Credit","Promo code":"TST2022"}',
#        '{"Promo code":"","Payment Method":"Debit"}',
#        '{"Tokenized Pay":"Apple Pay","Payment Method":"Debit","Promo code":"VEHICLEVIRGINS"}',
#        '{"Payment Method":"Venmo","Tokenized Pay":"","Promo code":""}'],
#       dtype=object)

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# Build pivot tables of occurences/counts of each event for each user for correlation analysis:

# %%
user_event_featuremap_occurence = pd.pivot_table(data_filtered[['userid', 'event_name']], index='userid', columns='event_name', aggfunc=lambda x: 1 if len(x) > 0 else 0).fillna(0)
user_event_featuremap_occurence.head()
# Out:
# event_name                        Account History Transaction Details  \
# userid
# 0006869712ec9841dc36234bce245203                                  1.0
# 00596aa4edee32815aaf4aad659c484e                                  0.0
# 007b54670d72df309afd87befcbb63db                                  0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                                  0.0
# 01529f53aaba5b512168d432d5650556                                  1.0
#
# event_name                        Account Setup Profile Skip  \
# userid
# 0006869712ec9841dc36234bce245203                         0.0
# 00596aa4edee32815aaf4aad659c484e                         0.0
# 007b54670d72df309afd87befcbb63db                         0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         0.0
# 01529f53aaba5b512168d432d5650556                         0.0
#
# event_name                        Account Setup Skip  \
# userid
# 0006869712ec9841dc36234bce245203                 0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0
# 007b54670d72df309afd87befcbb63db                 0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0
# 01529f53aaba5b512168d432d5650556                 0.0
#
# event_name                        Add Payment Method Failed  \
# userid
# 0006869712ec9841dc36234bce245203                        0.0
# 00596aa4edee32815aaf4aad659c484e                        0.0
# 007b54670d72df309afd87befcbb63db                        0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                        1.0
# 01529f53aaba5b512168d432d5650556                        0.0
#
# event_name                        Add Payment Method Success  \
# userid
# 0006869712ec9841dc36234bce245203                         1.0
# 00596aa4edee32815aaf4aad659c484e                         1.0
# 007b54670d72df309afd87befcbb63db                         1.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         1.0
# 01529f53aaba5b512168d432d5650556                         1.0
#
# event_name                        Add Vehicle Break  Add Vehicle Failed  \
# userid
# 0006869712ec9841dc36234bce245203                0.0                 0.0
# 00596aa4edee32815aaf4aad659c484e                0.0                 0.0
# 007b54670d72df309afd87befcbb63db                1.0                 0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                0.0                 0.0
# 01529f53aaba5b512168d432d5650556                1.0                 0.0
#
# event_name                        Add Vehicle Success  Calculator Used  \
# userid
# 0006869712ec9841dc36234bce245203                  1.0              0.0
# 00596aa4edee32815aaf4aad659c484e                  1.0              0.0
# 007b54670d72df309afd87befcbb63db                  1.0              0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                  1.0              0.0
# 01529f53aaba5b512168d432d5650556                  1.0              0.0
#
# event_name                        Calculator View  ...  Order  \
# userid                                             ...
# 0006869712ec9841dc36234bce245203              0.0  ...    0.0
# 00596aa4edee32815aaf4aad659c484e              0.0  ...    1.0
# 007b54670d72df309afd87befcbb63db              0.0  ...    0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0              0.0  ...    0.0
# 01529f53aaba5b512168d432d5650556              0.0  ...    0.0
#
# event_name                        Reset Password Set  Sign Out  Sign Up Error  \
# userid
# 0006869712ec9841dc36234bce245203                 0.0       0.0            0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0       0.0            0.0
# 007b54670d72df309afd87befcbb63db                 0.0       0.0            0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0       0.0            0.0
# 01529f53aaba5b512168d432d5650556                 0.0       0.0            0.0
#
# event_name                        Sign Up Success  Subscription Premium  \
# userid
# 0006869712ec9841dc36234bce245203              0.0                   1.0
# 00596aa4edee32815aaf4aad659c484e              1.0                   1.0
# 007b54670d72df309afd87befcbb63db              1.0                   1.0
# 0136a8eeca5d16ac1a521dd0e27ecec0              0.0                   1.0
# 01529f53aaba5b512168d432d5650556              1.0                   1.0
#
# event_name                        Subscription Premium Cancel  \
# userid
# 0006869712ec9841dc36234bce245203                          0.0
# 00596aa4edee32815aaf4aad659c484e                          0.0
# 007b54670d72df309afd87befcbb63db                          0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                          0.0
# 01529f53aaba5b512168d432d5650556                          0.0
#
# event_name                        Subscription Premium Renew  \
# userid
# 0006869712ec9841dc36234bce245203                         1.0
# 00596aa4edee32815aaf4aad659c484e                         0.0
# 007b54670d72df309afd87befcbb63db                         0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         1.0
# 01529f53aaba5b512168d432d5650556                         0.0
#
# event_name                        Transaction Refund  Wallet Opened
# userid
# 0006869712ec9841dc36234bce245203                 0.0            0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0            0.0
# 007b54670d72df309afd87befcbb63db                 0.0            0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0            0.0
# 01529f53aaba5b512168d432d5650556                 0.0            0.0
#
# [5 rows x 23 columns]

# %%
user_event_featuremap_counts = pd.pivot_table(data_filtered[['userid', 'event_name']], index='userid', columns='event_name', aggfunc=len).fillna(0)
user_event_featuremap_counts.head()
# Out:
# event_name                        Account History Transaction Details  \
# userid
# 0006869712ec9841dc36234bce245203                                  2.0
# 00596aa4edee32815aaf4aad659c484e                                  0.0
# 007b54670d72df309afd87befcbb63db                                  0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                                  0.0
# 01529f53aaba5b512168d432d5650556                                  2.0
#
# event_name                        Account Setup Profile Skip  \
# userid
# 0006869712ec9841dc36234bce245203                         0.0
# 00596aa4edee32815aaf4aad659c484e                         0.0
# 007b54670d72df309afd87befcbb63db                         0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         0.0
# 01529f53aaba5b512168d432d5650556                         0.0
#
# event_name                        Account Setup Skip  \
# userid
# 0006869712ec9841dc36234bce245203                 0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0
# 007b54670d72df309afd87befcbb63db                 0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0
# 01529f53aaba5b512168d432d5650556                 0.0
#
# event_name                        Add Payment Method Failed  \
# userid
# 0006869712ec9841dc36234bce245203                        0.0
# 00596aa4edee32815aaf4aad659c484e                        0.0
# 007b54670d72df309afd87befcbb63db                        0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                        1.0
# 01529f53aaba5b512168d432d5650556                        0.0
#
# event_name                        Add Payment Method Success  \
# userid
# 0006869712ec9841dc36234bce245203                         1.0
# 00596aa4edee32815aaf4aad659c484e                         2.0
# 007b54670d72df309afd87befcbb63db                         1.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         1.0
# 01529f53aaba5b512168d432d5650556                         1.0
#
# event_name                        Add Vehicle Break  Add Vehicle Failed  \
# userid
# 0006869712ec9841dc36234bce245203                0.0                 0.0
# 00596aa4edee32815aaf4aad659c484e                0.0                 0.0
# 007b54670d72df309afd87befcbb63db                1.0                 0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                0.0                 0.0
# 01529f53aaba5b512168d432d5650556                1.0                 0.0
#
# event_name                        Add Vehicle Success  Calculator Used  \
# userid
# 0006869712ec9841dc36234bce245203                  1.0              0.0
# 00596aa4edee32815aaf4aad659c484e                  1.0              0.0
# 007b54670d72df309afd87befcbb63db                  1.0              0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                  1.0              0.0
# 01529f53aaba5b512168d432d5650556                  1.0              0.0
#
# event_name                        Calculator View  ...  Order  \
# userid                                             ...
# 0006869712ec9841dc36234bce245203              0.0  ...    0.0
# 00596aa4edee32815aaf4aad659c484e              0.0  ...    3.0
# 007b54670d72df309afd87befcbb63db              0.0  ...    0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0              0.0  ...    0.0
# 01529f53aaba5b512168d432d5650556              0.0  ...    0.0
#
# event_name                        Reset Password Set  Sign Out  Sign Up Error  \
# userid
# 0006869712ec9841dc36234bce245203                 0.0       0.0            0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0       0.0            0.0
# 007b54670d72df309afd87befcbb63db                 0.0       0.0            0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0       0.0            0.0
# 01529f53aaba5b512168d432d5650556                 0.0       0.0            0.0
#
# event_name                        Sign Up Success  Subscription Premium  \
# userid
# 0006869712ec9841dc36234bce245203              0.0                   1.0
# 00596aa4edee32815aaf4aad659c484e              1.0                   1.0
# 007b54670d72df309afd87befcbb63db              1.0                   1.0
# 0136a8eeca5d16ac1a521dd0e27ecec0              0.0                   1.0
# 01529f53aaba5b512168d432d5650556              1.0                   1.0
#
# event_name                        Subscription Premium Cancel  \
# userid
# 0006869712ec9841dc36234bce245203                          0.0
# 00596aa4edee32815aaf4aad659c484e                          0.0
# 007b54670d72df309afd87befcbb63db                          0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                          0.0
# 01529f53aaba5b512168d432d5650556                          0.0
#
# event_name                        Subscription Premium Renew  \
# userid
# 0006869712ec9841dc36234bce245203                         1.0
# 00596aa4edee32815aaf4aad659c484e                         0.0
# 007b54670d72df309afd87befcbb63db                         0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                         2.0
# 01529f53aaba5b512168d432d5650556                         0.0
#
# event_name                        Transaction Refund  Wallet Opened
# userid
# 0006869712ec9841dc36234bce245203                 0.0            0.0
# 00596aa4edee32815aaf4aad659c484e                 0.0            0.0
# 007b54670d72df309afd87befcbb63db                 0.0            0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                 0.0            0.0
# 01529f53aaba5b512168d432d5650556                 0.0            0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# We analysed the attributes of all of the event types and chose the features, which can correlate with the target event. Here we are extracting such features:

# %%
# attr from events
# events
has_cancel_by_userid = pd.pivot_table(data_filtered[['userid', 'event_name']], index='userid', columns='event_name', aggfunc=lambda x: 1 if len(x) > 0 else 0).fillna(0)[[target_event]]

amount_data = pd.DataFrame(data=data_filtered[['userid']], columns=['userid'])
amount_data['Refund amount'] = data_filtered.event_attributes_d.apply(lambda x: float(x['Amount']) if 'Amount' in x.keys() else None)
amount_data = amount_data.groupby(by='userid').sum()

subscription_type_data = pd.DataFrame(data=data_filtered[['userid']], columns=['userid'])
subscription_type_data['Subscription type'] = data_filtered.event_attributes_d.apply(lambda x: x['Membership Type'] if 'Membership Type' in x.keys() else None)
subscription_type_data_yearly = subscription_type_data.groupby(by='userid').agg(lambda x: 1 if 'Yearly' in x.values else 0)
subscription_type_data_monthly = subscription_type_data.groupby(by='userid').agg(lambda x: 1 if 'Monthly' in x.values else 0)
subscription_type_data = subscription_type_data_yearly.merge(subscription_type_data_monthly, left_index=True, right_index=True)
subscription_type_data = subscription_type_data.rename(columns={'Subscription type_x': 'Yearly subscription', 'Subscription type_y': 'Monthly subscription'})

promocode_data = pd.DataFrame(data=data_filtered[['userid']], columns=['userid'])
promocode_data['Has promo code'] = data_filtered.event_attributes_d.apply(lambda x: 1 if 'Promo code' in x.keys() and len(x['Promo code']) else 0)
promocode_data = promocode_data.groupby(by='userid').max()

chat_opened_from_data = pd.DataFrame(data=data_filtered[['userid']], columns=['userid'])
chat_opened_from_data['Chat Conversation Opened From'] = data_filtered.event_attributes_d.apply(
    lambda x: x['From'] if 'From' in x.keys() and len(x['From']) else None
)
chat_opened_from_data = chat_opened_from_data.set_index('userid')
chat_opened_from_data = pd.get_dummies(chat_opened_from_data, prefix_sep=' ')
chat_opened_from_data = chat_opened_from_data.groupby(by='userid').sum()

# merges
attributes_data_by_user = amount_data.copy()
attributes_data_by_user = attributes_data_by_user.merge(subscription_type_data, left_index=True, right_index=True)
attributes_data_by_user = attributes_data_by_user.merge(promocode_data, left_index=True, right_index=True)
attributes_data_by_user = attributes_data_by_user.merge(chat_opened_from_data, left_index=True, right_index=True)
attributes_data_by_user = attributes_data_by_user.merge(has_cancel_by_userid, left_index=True, right_index=True)

# %%
attributes_data_by_user.head()
# Out:
#                                   Refund amount  Yearly subscription  \
# userid
# 0006869712ec9841dc36234bce245203            0.0                    1
# 00596aa4edee32815aaf4aad659c484e            0.0                    0
# 007b54670d72df309afd87befcbb63db            0.0                    0
# 0136a8eeca5d16ac1a521dd0e27ecec0            0.0                    0
# 01529f53aaba5b512168d432d5650556            0.0                    0
#
#                                   Monthly subscription  Has promo code  \
# userid
# 0006869712ec9841dc36234bce245203                     1               0
# 00596aa4edee32815aaf4aad659c484e                     1               0
# 007b54670d72df309afd87befcbb63db                     1               0
# 0136a8eeca5d16ac1a521dd0e27ecec0                     1               0
# 01529f53aaba5b512168d432d5650556                     1               0
#
#                                   Chat Conversation Opened From Dashboard  \
# userid
# 0006869712ec9841dc36234bce245203                                        0
# 00596aa4edee32815aaf4aad659c484e                                        0
# 007b54670d72df309afd87befcbb63db                                        2
# 0136a8eeca5d16ac1a521dd0e27ecec0                                        0
# 01529f53aaba5b512168d432d5650556                                        0
#
#                                   Chat Conversation Opened From Deeplink  \
# userid
# 0006869712ec9841dc36234bce245203                                       0
# 00596aa4edee32815aaf4aad659c484e                                       0
# 007b54670d72df309afd87befcbb63db                                       0
# 0136a8eeca5d16ac1a521dd0e27ecec0                                       0
# 01529f53aaba5b512168d432d5650556                                       0
#
#                                   Chat Conversation Opened From Menu  \
# userid
# 0006869712ec9841dc36234bce245203                                   0
# 00596aa4edee32815aaf4aad659c484e                                   0
# 007b54670d72df309afd87befcbb63db                                   2
# 0136a8eeca5d16ac1a521dd0e27ecec0                                   0
# 01529f53aaba5b512168d432d5650556                                   0
#
#                                   Chat Conversation Opened From Transaction Details  \
# userid
# 0006869712ec9841dc36234bce245203                                                  0
# 00596aa4edee32815aaf4aad659c484e                                                  0
# 007b54670d72df309afd87befcbb63db                                                  0
# 0136a8eeca5d16ac1a521dd0e27ecec0                                                  0
# 01529f53aaba5b512168d432d5650556                                                  0
#
#                                   Subscription Premium Cancel
# userid
# 0006869712ec9841dc36234bce245203                          0.0
# 00596aa4edee32815aaf4aad659c484e                          0.0
# 007b54670d72df309afd87befcbb63db                          0.0
# 0136a8eeca5d16ac1a521dd0e27ecec0                          0.0
# 01529f53aaba5b512168d432d5650556                          0.0

# %% [markdown]
# ## Correlations computation

# %% [markdown]
# ### General

# %%
user_event_featuremap_occurence.corr()[[target_event]].sort_values(by=target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Subscription Premium Renew                             -0.207159
# Order                                                  -0.171091
# Add Payment Method Failed                              -0.028738
# Reset Password Set                                     -0.023057
# Sign Out                                               -0.017172
# Add Vehicle Failed                                     -0.007425
# Calculator Used                                        -0.002639
# Email Confirmation Success                              0.009060
# Sign Up Error                                           0.022141
# Add Vehicle Break                                       0.023430
# Calculator View                                         0.041036
# Add Vehicle Success                                     0.048770
# Account Setup Skip                                      0.085541
# Subscription Premium                                    0.098020
# Sign Up Success                                         0.099425
# Add Payment Method Success                              0.111414
# Account History Transaction Details                     0.112931
# Account Setup Profile Skip                              0.128178
# Transaction Refund                                      0.268686
# Wallet Opened                                           0.273945
# Chat Conversation Opened                                0.448098
# Chat Conversation Started                               0.619813
# Subscription Premium Cancel                             1.000000

# %%
user_event_featuremap_counts.corr(method='spearman')[[target_event]].sort_values(by=target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Subscription Premium Renew                             -0.206757
# Order                                                  -0.186232
# Add Payment Method Failed                              -0.031412
# Reset Password Set                                     -0.022951
# Sign Out                                               -0.017377
# Add Vehicle Failed                                     -0.008356
# Add Vehicle Success                                    -0.003593
# Calculator Used                                         0.000297
# Email Confirmation Success                              0.012027
# Sign Up Error                                           0.020742
# Add Vehicle Break                                       0.026469
# Calculator View                                         0.039618
# Account Setup Skip                                      0.080556
# Add Payment Method Success                              0.093075
# Account History Transaction Details                     0.094811
# Sign Up Success                                         0.097622
# Subscription Premium                                    0.098080
# Account Setup Profile Skip                              0.126011
# Wallet Opened                                           0.258102
# Transaction Refund                                      0.266476
# Chat Conversation Opened                                0.449668
# Chat Conversation Started                               0.601528
# Subscription Premium Cancel                             1.000000

# %% [markdown]
# The user intending to write to Help Desk will likely cancel his subscription. <br>
# Interest to Balance Sheet [ e.g., Wallet Opened / Transactional Refund ] <br>
# also negative sign [may be an expression of user`s unsatisfaction of service] <br>
#
# Active [high number of orders] and loyal [subscription renew] users are naturally less prone to Subscription Premium Cancel

# %%
attributes_data_by_user.corr(method='spearman')[[target_event]].sort_values(by=target_event)
# Out:
#                                                    Subscription Premium Cancel
# Refund amount                                                        -0.267861
# Yearly subscription                                                  -0.085511
# Has promo code                                                       -0.017656
# Chat Conversation Opened From Dashboard                              -0.016683
# Chat Conversation Opened From Deeplink                                0.052512
# Monthly subscription                                                  0.058552
# Chat Conversation Opened From Transaction Details                     0.129043
# Chat Conversation Opened From Menu                                    0.473684
# Subscription Premium Cancel                                           1.000000

# %% [markdown]
# We can see that Subscription Premium Cancel higly relatated with Refunds(**reminder: amount is negative number!**) <br>
# A yearly subscription is a tiny bit better than a monthly (maybe because a long-term subscription is a sign of firm intention to use the app)<br>
# Opening Chat Conversation from Menu is a signal for anxiety about user loyalty <br>

# %% [markdown]
# ### Analysis by regions

# %%
data_filtered[['userid', 'user_state']].groupby(by='user_state').nunique().sort_values(by='userid', ascending=False)
# Out:
#             userid
# user_state
# CA             342
# TX             192
# FL              63
# IL              41
# NY              34
# VA              26
# NJ              17
# MD              10
# MA               8
# PA               7
# OK               6
# IN               6
# AZ               5
# CT               4
# OH               3
# NH               3
# WI               3
# DC               3
# NC               3
# NM               2
# KY               2
# AR               2
# IA               2
# DE               2
# CO               2
# TN               1
# UT               1
# VT               1
# AL               1
# MT               1
# OR               1
# NV               1
# MI               1
# KS               1
# GA               1
# WV               1

# %% [markdown]
# We can see, that solid amount of data comes from CA and TX states only.
# Let's compare them with the whole dataset.

# %%
def event_occurence_featuremap_correlation(df, target):
    user_event_featuremap = pd.pivot_table(df[['userid', 'event_name']], index='userid', columns='event_name', aggfunc=lambda x: 1 if len(x) > 0 else 0).fillna(0)
    return user_event_featuremap.corr()[[target]].sort_values(by=target)

# %%
def event_counts_featuremap_correlation(df, target, method='spearman'):
    user_event_featuremap_counts = pd.pivot_table(df[['userid', 'event_name']], index='userid', columns='event_name', aggfunc=len).fillna(0)
    return user_event_featuremap_counts.corr(method=method)[[target]].sort_values(by=target)

# %% [markdown]
# #### CA

# %%
ca_data = data_filtered[data_filtered.user_state == 'CA'].copy()
event_occurence_featuremap_correlation(ca_data, target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Subscription Premium Renew                             -0.212814
# Order                                                  -0.169417
# Add Vehicle Failed                                     -0.036790
# Sign Out                                               -0.024209
# Add Payment Method Failed                              -0.012278
# Email Confirmation Success                              0.004060
# Calculator Used                                         0.010369
# Add Vehicle Break                                       0.014122
# Sign Up Error                                           0.079711
# Calculator View                                         0.102828
# Account History Transaction Details                     0.119434
# Sign Up Success                                         0.120096
# Subscription Premium                                    0.128915
# Account Setup Skip                                      0.148785
# Add Vehicle Success                                     0.151032
# Account Setup Profile Skip                              0.152073
# Add Payment Method Success                              0.152243
# Transaction Refund                                      0.280692
# Wallet Opened                                           0.388922
# Chat Conversation Opened                                0.433085
# Chat Conversation Started                               0.587444
# Subscription Premium Cancel                             1.000000

# %%
event_counts_featuremap_correlation(ca_data, target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Subscription Premium Renew                             -0.198920
# Order                                                  -0.180736
# Add Vehicle Failed                                     -0.036491
# Sign Out                                               -0.020070
# Add Payment Method Failed                              -0.015614
# Email Confirmation Success                              0.009669
# Calculator Used                                         0.015507
# Add Vehicle Break                                       0.025230
# Add Vehicle Success                                     0.045176
# Sign Up Error                                           0.074333
# Calculator View                                         0.084274
# Account History Transaction Details                     0.090161
# Add Payment Method Success                              0.095606
# Sign Up Success                                         0.114901
# Subscription Premium                                    0.123403
# Account Setup Skip                                      0.137849
# Account Setup Profile Skip                              0.144206
# Transaction Refund                                      0.283470
# Wallet Opened                                           0.352619
# Chat Conversation Opened                                0.433997
# Chat Conversation Started                               0.580735
# Subscription Premium Cancel                             1.000000

# %% [markdown]
# #### TX

# %%
tx_data = data_filtered[data_filtered.user_state == 'TX'].copy()
event_occurence_featuremap_correlation(tx_data, target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Order                                                  -0.182404
# Subscription Premium Renew                             -0.162557
# Email Confirmation Success                             -0.157985
# Add Payment Method Failed                              -0.069697
# Sign Out                                               -0.059358
# Calculator View                                        -0.008842
# Add Vehicle Success                                    -0.001945
# Subscription Premium                                    0.001685
# Account Setup Skip                                      0.009112
# Calculator Used                                         0.013025
# Add Vehicle Break                                       0.021301
# Add Payment Method Success                              0.044984
# Sign Up Success                                         0.052840
# Account Setup Profile Skip                              0.064036
# Account History Transaction Details                     0.088231
# Add Vehicle Failed                                      0.134692
# Wallet Opened                                           0.167586
# Transaction Refund                                      0.271525
# Chat Conversation Opened                                0.500320
# Chat Conversation Started                               0.599153
# Subscription Premium Cancel                             1.000000

# %%
event_counts_featuremap_correlation(tx_data, target_event)
# Out:
# event_name                           Subscription Premium Cancel
# event_name
# Subscription Premium Renew                             -0.179407
# Order                                                  -0.179375
# Email Confirmation Success                             -0.148580
# Add Payment Method Failed                              -0.070505
# Sign Out                                               -0.063831
# Add Vehicle Success                                    -0.046124
# Calculator View                                        -0.007424
# Subscription Premium                                    0.002806
# Account Setup Skip                                      0.008650
# Calculator Used                                         0.011068
# Add Vehicle Break                                       0.020836
# Account History Transaction Details                     0.053745
# Sign Up Success                                         0.053824
# Add Payment Method Success                              0.057690
# Account Setup Profile Skip                              0.065099
# Add Vehicle Failed                                      0.133690
# Wallet Opened                                           0.181006
# Transaction Refund                                      0.269505
# Chat Conversation Opened                                0.473630
# Chat Conversation Started                               0.567938
# Subscription Premium Cancel                             1.000000

# %% [markdown]
# ### Analysis by platform

# %%
data_filtered.event_platform.unique()
# Out:
# array(['android', 'outofband', 'ios'], dtype=object)

# %%
user_to_os = pd.pivot_table(
    data_filtered[['userid', 'event_platform']], 
    index='userid', 
    columns='event_platform', 
    aggfunc=lambda x: 1 if len(x) > 0 else 0
).fillna(0).drop(columns='outofband')

# %%
pd.merge(
    pd.pivot_table(
        data_filtered[['userid', 'event_name']], 
        index='userid', 
        columns='event_name', 
        aggfunc=lambda x: 1 if len(x) > 0 else 0
    ).fillna(0), 
    user_to_os, 
    left_index=True, 
    right_index=True
).corr()[['android', 'ios']]
# Out:
#                                       android       ios
# Account History Transaction Details  0.039301  0.038362
# Account Setup Profile Skip           0.012029  0.010498
# Account Setup Skip                  -0.024634  0.034704
# Add Payment Method Failed            0.041943 -0.022148
# Add Payment Method Success           0.089164  0.136874
# Add Vehicle Break                   -0.102296  0.126336
# Add Vehicle Failed                  -0.052675  0.056626
# Add Vehicle Success                  0.058670  0.126055
# Calculator Used                     -0.018644  0.046056
# Calculator View                     -0.022231  0.069789
# Chat Conversation Opened            -0.021524  0.090904
# Chat Conversation Started            0.142329 -0.072167
# Email Confirmation Success          -0.093759  0.135560
# Order                                0.041874  0.011821
# Reset Password Set                  -0.026288  0.028260
# Sign Out                             0.189633 -0.159797
# Sign Up Error                        0.015129 -0.011380
# Sign Up Success                      0.023751  0.162181
# Subscription Premium                 0.035740  0.137316
# Subscription Premium Cancel          0.053770 -0.007643
# Subscription Premium Renew          -0.091005 -0.018682
# Transaction Refund                   0.009676  0.017676
# Wallet Opened                        0.072202  0.006397
# android                              1.000000 -0.914131
# ios                                 -0.914131  1.000000

# %%
pd.merge(
    pd.pivot_table(
        data_filtered[['userid', 'event_name']], 
        index='userid', 
        columns='event_name', 
        aggfunc=len
    ).fillna(0), 
    user_to_os, 
    left_index=True, 
    right_index=True
).corr(method='spearman')[['android', 'ios']]
# Out:
#                                       android       ios
# Account History Transaction Details  0.074704  0.002833
# Account Setup Profile Skip           0.012575  0.009935
# Account Setup Skip                  -0.024744  0.034812
# Add Payment Method Failed            0.040046 -0.020298
# Add Payment Method Success           0.070557  0.119675
# Add Vehicle Break                   -0.102801  0.126784
# Add Vehicle Failed                  -0.052675  0.056626
# Add Vehicle Success                  0.070778  0.084086
# Calculator Used                     -0.018831  0.046784
# Calculator View                     -0.005454  0.054265
# Chat Conversation Opened            -0.029042  0.095000
# Chat Conversation Started            0.221937 -0.149977
# Email Confirmation Success          -0.093483  0.134940
# Order                                0.021387  0.028367
# Reset Password Set                  -0.026288  0.028260
# Sign Out                             0.190337 -0.160533
# Sign Up Error                        0.015129 -0.011380
# Sign Up Success                      0.027769  0.157518
# Subscription Premium                 0.035740  0.137316
# Subscription Premium Cancel          0.047581 -0.001776
# Subscription Premium Renew          -0.094706 -0.020155
# Transaction Refund                   0.010306  0.017503
# Wallet Opened                        0.072631  0.005194
# android                              1.000000 -0.914131
# ios                                 -0.914131  1.000000

# %% [markdown]
# As we can see, the dissimilarity between users on different operating systems is insignificant. Only `Sign Up Success` and `Sign Out` are slightly different, probably due to the typical authentification mechanism (e.g., AppleID vs. Google Account).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The user intending to write to Help Desk will likely cancel his subscription. <br>
# Interest to Balance Sheet [ e.g., Wallet Opened / Transactional Refund ] <br>
# also negative sign [may be an expression of user`s unsatisfaction of service] <br>
#
# Active [high number of orders] and loyal [subscription renew] users are naturally less prone to Subscription Premium Cancel
#
# We can see that Subscription Premium Cancel higly relatated with Refunds(**reminder: amount is negative number!**) <br>
# A yearly subscription is a tiny bit better than a monthly (maybe because a long-term subscription is a sign of firm intention to use the app)<br>
# Opening Chat Conversation from Menu is a signal for anxiety about user loyalty <br>
#
# Due to our analysis, regions of users and platforms are insignificant <br>
